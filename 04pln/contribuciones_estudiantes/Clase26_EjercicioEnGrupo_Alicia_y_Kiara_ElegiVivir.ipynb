# %% [markdown]
# ## Coding Exercise #0509

# %%
import nltk
from numpy.random import randint, seed
from sklearn.feature_extraction.text import CountVectorizer

# %% [markdown]
# ### 1. n-Gram based autofill:

# %%
# !pip install EbookLib
# Out:
# Collecting EbookLib
#   Downloading ebooklib-0.19-py3-none-any.whl.metadata (4.1 kB)
# Requirement already satisfied: lxml in /usr/local/lib/python3.11/dist-packages (from EbookLib) (5.4.0)
# Requirement already satisfied: six in /usr/local/lib/python3.11/dist-packages (from EbookLib) (1.17.0)
# Downloading ebooklib-0.19-py3-none-any.whl (39 kB)
# Installing collected packages: EbookLib
# Successfully installed EbookLib-0.19

# %%
# !pip install ebooklib
# !pip install beautifulsoup4
# Out:
# Requirement already satisfied: ebooklib in /usr/local/lib/python3.11/dist-packages (0.19)
# Requirement already satisfied: lxml in /usr/local/lib/python3.11/dist-packages (from ebooklib) (5.4.0)
# Requirement already satisfied: six in /usr/local/lib/python3.11/dist-packages (from ebooklib) (1.17.0)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.11/dist-packages (4.13.4)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4) (2.7)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4) (4.14.1)

# %%
from ebooklib import epub
from bs4 import BeautifulSoup
import ebooklib

def extraer_texto_epub(ruta):
    libro = epub.read_epub(ruta)
    texto_total = ''
    for item in libro.get_items():
        if item.get_type() == ebooklib.ITEM_DOCUMENT:
            contenido = item.get_content()
            soup = BeautifulSoup(contenido, 'html.parser')
            texto_total += soup.get_text()
    return texto_total

# %%
text = extraer_texto_epub('elegi_vivir.epub')

# %%
text
# Out:
# '\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n \nÍndice\nCubierta\nAGRADECIMIENTOS\nPRÓLOGO\nANTES DEL ACCIDENTE\nEL ACCIDENTE\nEL RESCATE\nLOS RECUERDOS DE UN AMIGO: DIEGO ZANOLLI\nEL DESPERTAR\nEN LA UCI\nLOS PRIMEROS DÍAS EN LA CLÍNICA\nTONELADAS DE CARIÑO\nEL COMIENZO DE MI REHABILITACIÓN\nLA CUENTA REGRESIVA\nEL TESTIMONIO DE LEONOR\nPREPARANDO EL PRIMER VIAJE\nLA LLEGADA A FILADELFIA Y A MOSS REHAB INSTITUTE\nEL INICIO DE LA TERAPIA FÍSICA\nLA TERAPIA OCUPACIONAL Y LA ACEPTACIÓN\nLA MOTIVADORA TERAPIA RECREACIONAL\nDE REGRESO A CHILE\nOTRA VEZ EN CASA\nPREPARANDO MI RETORNO A CLASES\nOTRA VEZ A MOSS\nEL ARCO IRIS DESPUÉS DE LA LLUVIA\nOTRO VIAJE TERMINA\nRETOMANDO MIS ESTUDIOS\nLA TELETÓN\nMI VIDA CONTINÚA\nEPÍLOGO\nCUADERNO DE IMÁGENES\nCréditos\n\n\n\n\n\n\n\n\n \nA mi mamá, por su entrega incondicional. \nA mi familia y amigos, por su cariño y apoyo. \nY a Ricardo, por siempre creer en mí. \n\n\n\n\n\n\n\n\nAGRADECIMIENTOS \n \nNo fue fácil decidirme a publicar este libro. Para mí es mucho más que un relato: es mi vida. Pero me sirvió mucho escribirlo y espero que su lectura sirva también a otras personas. \nQuiero agradecer a las escritoras Ana María Güiraldes y Soledad Birrell por darme el primer impulso que necesitaba y por animarme a terminar lo empezado. \nTambién a la periodista Susana Roccatagliata por guiarme en el complicado mundo de las editoriales. Sus consejos y su amistad fueron fundamentales. \nA la periodista Jacqueline Hott por ayudarme con cariño a darle a mi libro el toque literario que le faltaba. \nA la editora Lissette Sepúlveda por su dedicación y comprensión. Y a la editorial Random House Mondadori por permitirme convertir mi sueño en realidad. \nFinalmente, agradezco a mis papás, hermanos, a mi familia y amigos, a los médicos que me atendieron con afecto, y a Ricardo, por acompañarme durante todo el camino. Gracias por no permitirme caer. \n\n\n\n\n\n\n\n\nPRÓLOGO \n \nEscribo estas líneas a casi diez meses desde el accidente de mi hija Daniela. No es mucho tiempo, las heridas físicas y las del alma aún no terminan de cicatrizar. Los días van pasando, a veces son buenos y a veces malos. Nuestra vida gira en torno a cosas distintas. En un día bueno, nos puede enorgullecer un progreso de Daniela. En un día malo, la pena nos abruma y sólo dan ganas de llorar. \nHemos conocido aspectos maravillosos del ser humano y otros muy mezquinos. El mundo completo ha cambiado a nuestro alrededor. Creo que uno nunca está preparado para el sufrimiento, menos para ver sufrir a un hijo. Ilusamente tenemos un sentimiento de invulnerabilidad. Los grandes remezones nos aterrizan. \nA veces siento que he sido bendecida. He podido vivir un milagro. No sólo porque Daniela esté viva, también por ser su madre y testigo de su fortaleza. ¿Cómo puede seguir siendo tan dulce con las personas? Su sonrisa se prodiga a todos los que la rodean. Las rabias y frustraciones sólo las conocemos los muy íntimos. Nunca ha desquitado sus malos momentos contra el mundo. ¡Hay tantos amargados con problemas tan mínimos! \nMi hija nos ha dado tantas lecciones. Todo lo que se propone lo consigue. No importa cuánto haya que luchar o cuán difícil sea. Ella peleará con todas sus fuerzas y lo logrará. Ya no me atrevo a pensar en sus limitaciones, ella no las considera. Su espíritu no tiene límites. \nEstoy segura de que Dios nos quiere mucho, ha permitido que Daniela siga a nuestro lado y que nos esté dando increíbles lecciones. Es imposible no cuestionarse nuestras prioridades o nuestras preocupaciones, todo se mira con un prisma distinto después del accidente. \nPoco a poco vamos recomponiendo nuestra vida de familia, la experiencia vivida nos ha unido. Hemos manifestado sentimientos que muchas veces uno se guarda y no expresa por vergüenza o simple dejación. \nHa habido momentos muy duros, penas inmensas, pero como dijo el Papa: el amor es más fuerte. El amor de Dios, de nuestra familia y de cientos de personas amigas nos ha permitido mantenernos a flote. ...

# %%
import re

def limpiar_texto(texto):
    texto = texto.lower()  # pasar todo a minúsculas
    texto = re.sub(r'\s+', ' ', texto)  # eliminar saltos de línea y espacios múltiples
    texto = re.sub(r'[“”‘’]', '', texto)  # comillas raras
    texto = texto.replace('\xa0', ' ')  # eliminar caracteres extraños
    return texto.strip()

corpus_limpio = limpiar_texto(text)

# %%
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
import numpy as np

# Crear el tokenizer
tokenizer = Tokenizer()
tokenizer.fit_on_texts([corpus_limpio])

total_palabras = len(tokenizer.word_index) + 1
print(f"Total de palabras únicas: {total_palabras}")

# Crear secuencias de entrenamiento
input_sequences = []
palabras = corpus_limpio.split()

for i in range(1, len(palabras)):
    secuencia = palabras[:i+1]
    codificada = tokenizer.texts_to_sequences([' '.join(secuencia)])[0]
    input_sequences.append(codificada)

# Pad sequences
secuencias_padded = pad_sequences(input_sequences, padding='pre')

# Separar en X e y
X = secuencias_padded[:, :-1]
y = secuencias_padded[:, -1]

# One-hot encode y
from tensorflow.keras.utils import to_categorical
y = to_categorical(y, num_classes=total_palabras)
# Out:
# Total de palabras únicas: 7856

# %% [markdown]
# #### 1.1. n-Gram trial run:

# %%
from sklearn.feature_extraction.text import CountVectorizer
import nltk

# %%
n = 3                                                            # Can be changed to a number equal or larger than 2.
n_min = n
n_max = n
n_gram_type = 'word'                                             # n-Gram with words.
vectorizer = CountVectorizer(ngram_range=(n_min, n_max), analyzer=n_gram_type)

# %%
n_grams = vectorizer.fit([corpus_limpio]).get_feature_names_out()            # Get the n-Grams as a list.
n_gram_cts = vectorizer.transform([corpus_limpio]).toarray()             #  The output is an array of array.
n_gram_cts = list(n_gram_cts[0])                                 # Convert into a simple list.

# %%
list(zip(n_grams,n_gram_cts))                                    # Make a list of tuples and show.
# Out:
# [('11 de agosto', np.int64(1)),
#  ('17 de diciembre', np.int64(1)),
#  ('1999 entré estudiar', np.int64(1)),
#  ('2002 empezó temprano', np.int64(1)),
#  ('2002 fue especialmente', np.int64(1)),
#  ('2002 fue un', np.int64(1)),
#  ('2003 antes del', np.int64(1)),
#  ('2003 estaba programada', np.int64(1)),
#  ('2003 llegué por', np.int64(1)),
#  ('2003 mis papás', np.int64(1)),
#  ('2003 sino también', np.int64(1)),
#  ('2004 daniela garcía', np.int64(1)),
#  ('2004 estas fotos', np.int64(1)),
#  ('2004 fui nuevamente', np.int64(1)),
#  ('2014 2004 daniela', np.int64(1)),
#  ('2014 penguin random', np.int64(1)),
#  ('21 22 de', np.int64(1)),
#  ('22 años no', np.int64(1)),
#  ('22 de noviembre', np.int64(2)),
#  ('280 piso santiago', np.int64(1)),
#  ('30 de octubre', np.int64(8)),
#  ('50 con vagones', np.int64(1)),
#  ('9789562584005 conversión formato', np.int64(1)),
#  ('abajo como siempre', np.int64(1)),
#  ('abajo tratando de', np.int64(1)),
#  ('abandonaban incluso intenté', np.int64(1)),
#  ('abandonaban jamás iba', np.int64(1)),
#  ('abandonando mi cuerpo', np.int64(1)),
#  ('abandonar el proscenio', np.int64(1)),
#  ('abandonar la casa', np.int64(1)),
#  ('abandonaría la terapia', np.int64(1)),
#  ('abandonó la uci', np.int64(1)),
#  ('abarrotada no dejaba', np.int64(1)),
#  ('abdominales en distintas', np.int64(1)),
#  ('abdominales levantar algunos', np.int64(1)),
#  ('abierta lo que', np.int64(1)),
#  ('abiertas para permitir', np.int64(1)),
#  ('abismante cómo iban', np.int64(1)),
#  ('abogado josé miguel', np.int64(1)),
#  ('abogados los de', np.int64(1)),
#  ('abracé con toda', np.int64(1)),
#  ('abracé en el', np.int64(1)),
#  ('abrazaba sin parar', np.int64(1)),
#  ('abrazaban tratando de', np.int64(1)),
#  ('abrazamos me pude', np.int64(1)),
#  ('abrazamos me sentí', np.int64(1)),
#  ('abrazara me dijera', np.int64(1)),
#  ('abrazarnos con mi', np.int64(1)),
#  ('abrazaron también había', np.int64(1)),
#  ('abrazos nunca había', np.int64(1)),
#  ('abrazó fuerte los', np.int64(1)),
#  ('abre el gancho', np.int64(1)),
#  ('abriendo un mundo', np.int64(1)),
#  ('abrigada mis papás', np.int64(1)),
#  ('abrigador aconsejó leonor', np.int64(1)),
#  ('abrigara porque íbamos', np.int64(1)),
#  ('abril de modo', np.int64(1)),
#  ('abrir la puerta', np.int64(1)),
#  ('abrir las cortinas', np.int64(1)),
#  ('abrir las ventanas', np.int64(1)),
#  ('abrir los distintos', np.int64(1)),
#  ('abrir los ojos', np.int64(1)),
#  ('abrir un humilde', np.int64(1)),
#  ('abrirla adentro sólo', np.int64(1)),
#  ('abrirla asentí las', np.int64(1)),
#  ('abrirla cuando ya', np.int64(1)),
#  ('abrirnos paso nos', np.int64(1)),
#  ('abrirá me explicó', np.int64(1)),
#  ('abrió de golpe', np.int64(1)),
#  ('abrió el mundo', np.int64(1)),
#  ('abrió el refrigerador', np.int64(1)),
#  ('abrió la puerta', np.int64(2)),
#  ('abrió otra vez', np.int64(1)),
#  ('abrió su maleta', np.int64(1)),
#  ('abro vuelvo sentir', np.int64(1)),
#  ('abruma sólo dan', np.int64(1)),
#  ('abrí con cuidado', np.int64(1)),
#  ('abrí el clóset', np.int64(1)),
#  ('abrí los ojos', np.int64(2)),
#  ('abría era ricardo', np.int64(1)),
#  ('abría los ojos', np.int64(1)),
#  ('abríamos nuestro consultorio', np.int64(1)),
#  ('absorber en muy', np.int64(1)),
#  ('absorta en mi', np.int64(1)),
#  ('abuela materna que', np.int64(1)),
#  ('abuelita ah no', np.int64(1)),
#  ('abuelita apretó usted', np.int64(1)),
#  ('abuelita desesperadas tratando', np.int64(1)),
#  ('abuelita ellos no', np.int64(1)),
#  ('abuelita en uno', np.int64(1)),
#  ('abuelita la cati', np.int64(1)),
#  ('abuelita la puerta', np.int64(1)),
#  ('abuelita llevó la', np.int64(1)),
#  ('abuelita materna qué', np.int64(1)),
#  ('abuelita me voy', np.int64(1)),
#  ('abuelita que nos', np.int64(1)),
#  ('abuelita te voy', np.int64(1)),
#  ('abuelita trataba de', np.int64(1)),
#  ('abuelita uno de', np.int64(1)),
#  ('abuelita yo salimos', np.int64(1)),
#  ('abuelo paterno los', np.int64(1)),
#  ('abuelo que te', np.int64(1)),
#  ('aburrido lejos de', np.int64(1)),
#  ('académicos de todo', np.int64(1)),
#  ('acarició la cabeza', np.int64(1)),
#  ('acarrearon la enorme', np.int64(1)),
#  ('acaso no saben', np.int64(1)),
#  ('acaso tendría que', np.int64(1)),
#  ('accedió llevarme hasta', np.int64(1)),
#  ('acceso atochado de', np.int64(1)),
#  ('accidentada en la', np.int64(1)),
#  ('accidentada los muchachos', np.int64(1)),
#  ('accidentada un grupo', np.int64(1)),
#  ('accidente así aunque', np.int64(1)),
#  ('accidente con el', np.int64(1)),
#  ('accidente cuáles actividades', np.int64(1)),
#  ('accidente de daniela', np.int64(1)),
#  ('accidente de mi', np.int64(2)),
#  ('accidente de pronto', np.int64(1)),
#  ('accidente despertó el', np.int64(1)),
#  ('accidente dónde estoy', np.int64(1)),
#  ('accidente el accidente', np.int64(1)),
#  ('accidente el rescate', np.int64(1)),
#  ('accidente el segundo', np.int64(1)),
#  ('accidente en el', np.int64(1)),
#  ('accidente en una', np.int64(1)),
#  ('accidente era increíble', np.int64(1)),
#  ('accidente es decir', np.int64(1)),
#  ('accidente es rico', np.int64(1)),
#  ('accidente exclamó no', np.int64(1)),
#  ('accidente formaran parte', np.int64(1)),
#  ('accidente fue causado', np.int64(1)),
#  ('accidente gasté mis', np.int64(1)),
#  ('accidente había llegado', np.int64(1)),
#  ('accidente he recibido', np.int64(1)),
#  ('accidente intentaba desarrollar', np.int64(1)),
#  ('accidente la felicidad', np.int64(1)),
#  ('accidente la inmovilidad', np.int64(1)),
#  ('accidente la locomotora', np.int64(1)),
#  ('accidente la rehabilitación', np.int64(1)),
#  ('accidente lloré lloré', np.int64(1)),
#  ('accidente luego me', np.int64(1)),
#  ('accidente mi familia', np.int64(1)),
#  ('accidente no estaba', np.int64(1)),
#  ('accidente no lo', np.int64(1)),
#  ('accidente no me', np.int64(1)),
#  ('accidente pensar que', np.int64(1)),
#  ('accidente pero jamás', np.int64(1)),
#  ('accidente poco poco', np.int64(1)),
#  ('accidente por favor', np.int64(1)),
#  ('accidente que ellos', np.int64(1)),
#  ('accidente que no', np.int64(1)),
#  ('accidente rafael yo', np.int64(1)),
#  ('accidente razón por', np.int64(1)),
#  ('accidente se podría', np.int64(1)),
#  ('accidente su coraje', np.int64(1)),
#  ('accidente sus consecuencias', np.int64(1)),
#  ('accidente todavía quiero', np.int64(1)),
#  ('accidente todo podría', np.int64(1)),
#  ('accidente través de', np.int64(1)),
#  ('accidente tuve mucho', np.int64(1)),
#  ('accidente uno de', np.int64(1)),
#  ('accidente yo estaba', np.int64(1)),
#  ('accidente yo lo', np.int64(1)),
#  ('accidentes vasculares encefálicos', np.int64(1)),
#  ('acciones que se', np.int64(1)),
#  ('acción qué quieres', np.int64(1)),
#  ('acelerador sin dar', np.int64(1)),
#  ('acento tan familiar', np.int64(1)),
#  ('acentuaba cada vez', np.int64(1)),
#  ('aceptación la motivadora', np.int64(1)),
#  ('aceptación una semana', np.int64(1)),
#  ('aceptar fue la', np.int64(1)),
#  ('aceptar lo ocurrido', np.int64(1)),
#  ('aceptar mi respuesta', np.int64(1)),
#  ('aceptar que ahora', np.int64(1)),
#  ('aceptar ser reserva', np.int64(1)),
#  ('aceptarlo mis papás', np.int64(1)),
#  ('aceptarlos edición en', np.int64(1)),
#  ('aceptarlos mí también', np.int64(1)),
#  ('acepté la propuesta', np.int64(1)),
#  ('aceptó una pastilla', np.int64(1)),
#  ('aceptó ya me', np.int64(1)),
#  ('acercaba al ver', np.int64(1)),
#  ('acercaba justo por', np.int64(1)),
#  ('acercaba la fecha', np.int64(1)),
#  ('acercaba la navidad', np.int64(1)),
#  ('acercaba mí sin', np.int64(1)),
#  ('acercaba se fueron', np.int64(1)),
#  ('acercaba un tren', np.int64(1)),
#  ('acercaba yo no', np.int64(1)),
#  ('acercaban los caballos', np.int64(1)),
#  ('acercado mucho más', np.int64(1)),
#  ('acercado mí permaneció', np.int64(1)),
#  ('acercando la fecha', np.int64(1)),
#  ('acercaron saludarme con', np.int64(1)),
#  ('acercarse el día', np.int64(1)),
#  ('acercarse le dije', np.int64(1)),
#  ('acercarse me preguntó', np.int64(1)),
#  ('acercarse saltando de', np.int64(1)),
#  ('acercarse se percató', np.int64(1)),
#  ('acercarse una joven', np.int64(1)),
#  ('acercábamos yo trataba', np.int64(1)),
#  ('acercó al hombre', np.int64(1)),
#  ('acercó con los', np.int64(1)),
#  ('acercó en un', np.int64(1)),
#  ('acercó eres tú', np.int64(1)),
#  ('acercó marco me', np.int64(1)),
#  ('acercó me acarició', np.int64(1)),
#  ('acercó me hizo', np.int64(1)),
#  ('acercó me preguntó', np.int64(1)),
#  ('acercó no sé', np.int64(1)),
#  ('acercó qué hacen', np.int64(1)),
#  ('acercó rafael araneda', np.int64(1)),
#  ('acercó tomándome de', np.int64(1)),
#  ('acercó un carabinero', np.int64(1)),
#  ('acercó una mujer', np.int64(1)),
#  ('acercó vio que', np.int64(1)),
#  ('acerqué algo insegura', np.int64(1)),
#  ('acerqué ellos ves', np.int64(1)),
#  ('acerqué pude ver', np.int64(1)),
#  ('aclamaba reconoció al', np.int64(1)),
#  ('aclarar que no', np.int64(1)),
#  ('acogedor pero me', np.int64(1)),
#  ('acogedora el hecho', np.int64(1)),
#  ('acogedora todo estaba', np.int64(1)),
#  ('acogida la gente', np.int64(1)),
#  ('acogida que incluso', np.int64(1)),
#  ('acomodaba por su', np.int64(1)),
#  ('acomodaban alegre me', np.int64(1)),
#  ('acomodándose muchos estudiantes', np.int64(1)),
#  ('acompañaba ese día', np.int64(1)),
#  ('acompañaba julie como', np.int64(1)),
#  ('acompañaba la salida', np.int64(1)),
#  ('acompañaban incluso dormían', np.int64(1)),
#  ('acompañaban mis familiares', np.int64(1)),
#  ('acompañada por algún', np.int64(1)),
#  ('acompañada por mis', np.int64(1)),
#  ('acompañada siempre por', np.int64(1)),
#  ('acompañado moss ahora', np.int64(1)),
#  ('acompañado por josé', np.int64(1)),
#  ('acompañados por los', np.int64(1)),
#  ('acompañamiento podía ser', np.int64(1)),
#  ('acompañando por algunas', np.int64(1)),
#  ('acompañando sus nietos', np.int64(1)),
#  ('acompañar en todo', np.int64(1)),
#  ('acompañar la caro', np.int64(1)),
#  ('acompañara compraba el', np.int64(1)),
#  ('acompañara después llegaron', np.int64(1)),
#  ('acompañara en el', np.int64(1)),
#  ('acompañarlos rancagua leonor', np.int64(1)),
#  ('acompañarme durante todo', np.int64(1)),
#  ('acompañaron guardar mi', np.int64(1)),
#  ('acompañaron mi hija', np.int64(1)),
#  ('acompañaron mis papás', np.int64(1)),
#  ('acompañarían por algún', np.int64(1)),
#  ('acompaño me contestó', np.int64(1)),
#  ('acompañándome en las', np.int64(1)),
#  ('acompañó buscar mi', np.int64(1)),
#  ('acompañó hasta el', np.int64(1)),
#  ('acompañó hasta santiago', np.int64(1)),
#  ('acompañó toda la', np.int64(1)),
#  ('aconsejaban para tratar', np.int64(1)),
#  ('aconsejó leonor daniela', np.int64(1)),
#  ('acontecía por un', np.int64(1)),
#  ('acontezca algo terrible', np.int64(1)),
#  ('acordaba bien qué', np.int64(1)),
#  ('acordaba de un', np.int64(1)),
#  ('acordaban de mí', np.int64(1)),
#  ('acordado de mí', np.int64(1)),
#  ('acordamos que de', np.int64(1)),
#  ('acordarme de la', np.int64(1)),
#  ('acordé de mi', np.int64(1)),
#  ('acordé de una', np.int64(1)),
#  ('acordó de la', np.int64(1)),
#  ('acostada sin moverme', np.int64(1)),
#  ('acostada sobre pequeñas', np.int64(1)),
#  ('acostar esperando que', np.int64(1)),
#  ('acostarme me costó', np.int64(1)),
#  ('acostumbra que los', np.int64(1)),
#  ('acostumbraba las manos', np.int64(1)),
#  ('acostumbraba no ver', np.int64(1)),
#  ('acostumbrada familiarizada con', np.int64(1)),
#  ('acostumbrada levantarme entre', np.int64(1)),
#  ('acostumbrada tener los', np.int64(1)),
#  ('acostumbrado al traqueteo', np.int64(1)),
#  ('acostumbrados cargar mi', np.int64(1)),
#  ('acostumbrando ellos lo', np.int64(1)),
#  ('acostumbrando las tinieblas', np.int64(1)),
#  ('acostumbrarme la rodilla', np.int64(1)),
#  ('acostumbrarme nuevamente mi', np.int64(1)),
#  ('acostumbrarse una apariencia', np.int64(1)),
#  ('acostumbrarse usar prótesis', np.int64(1)),
#  ('acreditaba apta para', np.int64(1)),
#  ('actitud de don', np.int64(1)),
#  ('actitud respetuosa el', np.int64(1)),
#  ('activada la palanca', np.int64(1)),
#  ('activadas por mi', np.int64(1)),
#  ('activar cada electrodo', np.int64(1)),
#  ('actives un electrodo', np.int64(1)),
#  ('actividad favorita ahí', np.int64(1)),
#  ('actividad física desde', np.int64(1)),
#  ('actividad que había', np.int64(1)),
#  ('actividad voluntaria que', np.int64(1)),
#  ('actividades de rehabilitación', np.int64(1)),
#  ('actividades de un', np.int64(1)),
#  ('actividades echaba de', np.int64(1)),
#  ('actividades iría de', np.int64(1)),
#  ('actividades que me', np.int64(1)),
#  ('actividades que nos', np.int64(1)),
#  ('actividades universitarias me', np.int64(1)),
#  ('activó la alarma', np.int64(1)),
#  ('actores prácticamente podíamos', np.int64(1)),
#  ('actuado de ese', np.int64(1)),
#  ('actual me decidí', np.int64(1)),
#  ('acuarela con flores', np.int64(1)),
#  ('acuario con pequeños', np.int64(1)),
#  ('acudir clases en', np.int64(1)),
#  ('acuerdo de su', np.int64(1)),
#  ('acuerdo extrajudicial después', np.int64(1)),
#  ('acuerdo nada de', np.int64(1)),
#  ('acuerdo que me', np.int64(1)),
#  ('acumulaban tarjetas regalos', np.int64(1)),
#  ('acumuladas en la', np.int64(1)),
#  ('acusar al abuelo', np.int64(1)),
#  ('acuérdate de que', np.int64(1)),
#  ('acá llamó alejandro', np.int64(1)),
#  ('acá me dije', np.int64(1)),
#  ('acá no bien', np.int64(1)),
#  ('adaptaciones mi ropa', np.int64(1)),
#  ('adaptaciones posibles le', np.int64(1)),
#  ('adaptaciones que creía', np.int64(1)),
#  ('adaptado con rampas', np.int64(1)),
#  ('adaptado para que', np.int64(1)),
#  ('adaptarnos los cambios', np.int64(1)),
#  ('adaptarse los cambios', np.int64(2)),
#  ('adaptaría ellas otra', np.int64(1)),
#  ('adaptó un baño', np.int64(1)),
#  ('adaptó unas tijeras', np.int64(1)),
#  ('adecuado para mi', np.int64(1)),
#  ('adecuado para una', np.int64(1)),
#  ('adelantado organizada por', np.int64(1)),
#  ('adelante al carro', np.int64(1)),
#  ('adelante al cumplirse', np.int64(1)),
#  ('adelante al llegar', np.int64(1)),
#  ('adelante aunque esa', np.int64(1)),
#  ('adelante durante mi', np.int64(1)),
#  ('adelante el dolor', np.int64(1)),
#  ('adelante eso me', np.int64(1)),
#  ('adelante estaba el', np.int64(1)),
#  ('adelante la gente', np.int64(1)),
#  ('adelante la verdad', np.int64(1)),
#  ('adelante las dos', np.int64(1)),
#  ('adelante le contesté', np.int64(1)),
#  ('adelante lo entienda', np.int64(1)),
#  ('adelante me fijé', np.int64(1)),
#  ('adelante mi último', np.int64(1)),
#  ('adelante nunca les', np.int64(1)),
#  ('adelante pensé que', np.int64(1)),
#  ('adelante pero ya', np.int64(1)),
#  ('adelante podría ir', np.int64(1)),
#  ('adelante sería suficiente', np.int64(1)),
#  ('adelante serían más', np.int64(1)),
#  ('adelante tener una', np.int64(1)),
#  ('adelantos antes de', np.int64(1)),
#  ('además acarrearon la', np.int64(1)),
#  ('además compartir con', np.int64(1)),
#  ('además de asegurarse', np.int64(1)),
#  ('además de eso', np.int64(1)),
#  ('además de estar', np.int64(1)),
#  ('además de la', np.int64(1)),
#  ('además de las', np.int64(1)),
#  ('además debía preparar', np.int64(1)),
#  ('además en el', np.int64(1)),
#  ('además en esa', np.int64(1)),
#  ('además era un', np.int64(1)),
#  ('además eran muy', np.int64(1)),
#  ('además estaba muy', np.int64(1)),
#  ('además extrañaba los', np.int64(1)),
#  ('además la estética', np.int64(1)),
#  ('además la integración', np.int64(1)),
#  ('además le produjo', np.int64(1)),
#  ('además me dolía', np.int64(1)),
#  ('además serviría de', np.int64(1)),
#  ('además sería únicamente', np.int64(1)),
#  ('además tenía contactos', np.int64(1)),
#  ('además todavía tenía', np.int64(2)),
#  ('además ya sólo', np.int64(1)),
#  ('adentro daniela estaba', np.int64(1)),
#  ('adentro fui llevada', np.int64(1)),
#  ('adentro seguro que', np.int64(1)),
#  ('adentro sólo había', np.int64(1)),
#  ('adentros tenemos tiempo', np.int64(1)),
#  ('adivinaba el cariño', np.int64(1)),
#  ('adiviné más tranquilo', np.int64(1)),
#  ('administrando muchos medicamentos', np.int64(1)),
#  ('administraron morfina pero', np.int64(1)),
#  ('admirada de que', np.int64(1)),
#  ('admitirlo pero debo', np.int64(1)),
#  ('adolescencia nos distanciamos', np.int64(1)),
#  ('adolfo ibáñez había', np.int64(1)),
#  ('adolorida en mi', np.int64(1)),
#  ('adonde me lo', np.int64(1)),
#  ('adornada sólo por', np.int64(1)),
#  ('adornos regalos recibidos', np.int64(1)),
#  ('adosar las sillas', np.int64(1)),
#  ('adquirir un scooter', np.int64(1)),
#  ('adrenalina corría por', np.int64(1)),
#  ('adulta había cerrado', np.int64(1)),
#  ('adversidad pronunció otra', np.int64(1)),
#  ('advertencias del papá', np.int64(1)),
#  ('advertido era que', np.int64(1)),
#  ('advertido que tendría', np.int64(1)),
#  ('advertir el aspecto', np.int64(1)),
#  ('advertí la preocupación', np.int64(1)),
#  ('advirtiéndome que no', np.int64(1)),
#  ('advirtió que sus', np.int64(1)),
#  ('adónde cuándo me', np.int64(1)),
#  ('aeropuerto me despedí', np.int64(1)),
#  ('aeropuerto me pareció', np.int64(1)),
#  ('aeropuerto nos ayudó', np.int64(1)),
#  ('afanaba en el', np.int64(1)),
#  ('afanaba en la', np.int64(1)),
#  ('afectado salía frecuentemente', np.int64(1)),
#  ('afectados especialmente el', np.int64(1)),
#  ('afectados habían quedado', np.int64(1)),
#  ('afectan nunca pensamos', np.int64(1)),
#  ('afectar más pero', np.int64(1)),
#  ('afectarme alguna vez', np.int64(1)),
#  ('afectaría su relación', np.int64(1)),
#  ('afecto de mi', np.int64(1)),
#  ('afecto me cambiaban', np.int64(1)),
#  ('afecto ricardo por', np.int64(1)),
#  ('afectuosos como él', np.int64(1)),
#  ('aferrada ese pensamiento', np.int64(1)),
#  ('afirmando mientras yo', np.int64(1)),
#  ('afirmar las manos', np.int64(1)),
#  ('afirmar una cuchara', np.int64(1)),
#  ('afirmé en los', np.int64(1)),
#  ('aflicción creció dentro', np.int64(1)),
#  ('afortunadamente mi cama', np.int64(1)),
#  ('afortunadamente poco poco', np.int64(1)),
#  ('afuera alguien se', np.int64(1)),
#  ('afuera de su', np.int64(1)),
#  ('afuera pasear un', np.int64(1)),
#  ('agarre se regula', np.int64(1)),
#  ('agarré la mano', np.int64(1)),
#  ('agitaban en la', np.int64(1)),
#  ('agitada su madre', np.int64(1)),
#  ('agolparon pedirle la', np.int64(1)),
#  ('agosto de 2003', np.int64(1)),
#  ('agosto de modo', np.int64(1)),
#  ('agosto se encontró', np.int64(1)),
#  ('agotada anunció mi', np.int64(1)),
#  ('agotada como cada', np.int64(1)),
#  ('agotada cómo hacerlo', np.int64(1)),
#  ('agotada de modo', np.int64(1)),
#  ('agotada la casa', np.int64(1)),
#  ('agotada por mi', np.int64(1)),
#  ('agotada sabía que', np.int64(1)),
#  ('agotada se sentía', np.int64(1)),
#  ('agotada todos los', np.int64(1)),
#  ('agotada yo empezaba', np.int64(1)),
#  ('agradable cómo me', np.int64(1)),
#  ('agradable encontrarse con', np.int64(1)),
#  ('agradable eso me', np.int64(1)),
#  ('agradable nos íbamos', np.int64(1)),
#  ('agradecer dios por', np.int64(1)),
#  ('agradecer las escritoras', np.int64(1)),
#  ('agradecer personalmente todos', np.int64(1)),
#  ('agradecer porque finalmente', np.int64(1)),
#  ('agradecer que hubiese', np.int64(1)),
#  ('agradecer suficiente todas', np.int64(1)),
#  ('agradecer suficientemente al', np.int64(1)),
#  ('agradecerle decirle cuan', np.int64(1)),
#  ('agradecerles lo suficiente', np.int64(2)),
#  ('agradecerles pero al', np.int64(1)),
#  ('agradecerles su apoyo', np.int64(1)),
#  ('agradecida por eso', np.int64(1)),
#  ('agradecida sigo andando', np.int64(1)),
#  ('agradecieron los médicos', np.int64(1)),
#  ('agradecimiento hacia ellos', np.int64(1)),
#  ('agradecimiento hacia esas', np.int64(1)),
#  ('agradecimientos no fue', np.int64(1)),
#  ('agradecimientos prólogo antes', np.int64(1)),
#  ('agradecí al doctor', np.int64(1)),
#  ('agradecí dios que', np.int64(1)),
#  ('agradecí mil veces', np.int64(1)),
#  ('agradecí su lindo', np.int64(1)),
#  ('agradecí tener los', np.int64(1)),
#  ('agradezco mis papás', np.int64(1)),
#  ('agrado pero si', np.int64(1)),
#  ('agregamos una cama', np.int64(1)),
#  ('agregué cómo va', np.int64(1)),
#  ('agregué estaba absorta', np.int64(1)),
#  ('agregó amablemente el', np.int64(1)),
#  ('agregó martín la', np.int64(1)),
#  ('agregó mi abuelita', np.int64(1)),
#  ('agregó mientras hablaba', np.int64(1)),
#  ('agua la sed', np.int64(1)),
#  ('agua lo hice', np.int64(1)),
#  ('agua para lavarla', np.int64(1)),
#  ('agua sobre su', np.int64(1)),
#  ('agua una puerta', np.int64(1)),
#  ('aguantaba tanto rato', np.int64(1)),
#  ('aguantar más de', np.int64(1)),
#  ('aguantara más cuando', np.int64(1)),
#  ('aguanté lo más', np.int64(1)),
#  ('agudizó el oído', np.int64(1)),
#  ('aguja en el', np.int64(1)),
#  ('aguja no debe', np.int64(1)),
#  ('agujas el dolor', np.int64(1)),
#  ('agujas parecían tener', np.int64(1)),
#  ('agujas se movían', np.int64(1)),
#  ('agujero al cruzar', np.int64(1)),
#  ('agujero en el', np.int64(2)),
#  ('ah bueno debería', np.int64(1)),
#  ('ah no entonces', np.int64(1)),
#  ('ah no sé', np.int64(1)),
#  ('ahora camina usando', np.int64(1)),
#  ('ahora con el', np.int64(1)),
#  ('ahora con las', np.int64(1)),
#  ('ahora de pie', np.int64(1)),
#  ('ahora divisé josé', np.int64(1)),
#  ('ahora el cuerpo', np.int64(1)),
#  ('ahora en adelante', np.int64(2)),
#  ('ahora en chile', np.int64(1)),
#  ('ahora era tan', np.int64(2)),
#  ('ahora es muy', np.int64(1)),
#  ('ahora estaban aprendiendo', np.int64(1)),
#  ('ahora está en', np.int64(1)),
#  ('ahora existen unas', np.int64(1)),
#  ('ahora formalmente era', np.int64(1)),
#  ('ahora fuese tan', np.int64(1)),
#  ('ahora había que', np.int64(1)),
#  ('ahora inexistentes se', np.int64(1)),
#  ('ahora la distancia', np.int64(1)),
#  ('ahora la medicina', np.int64(1)),
#  ('ahora las cosas', np.int64(1)),
#  ('ahora las fuerzas', np.int64(1)),
#  ('ahora las uso', np.int64(1)),
#  ('ahora lo estuve', np.int64(1)),
#  ('ahora los programan', np.int64(1)),
#  ('ahora me doy', np.int64(2)),
#  ('ahora me iba', np.int64(1)),
#  ('ahora me pareció', np.int64(1)),
#  ('ahora mi sueño', np.int64(1)),
#  ('ahora miraba entre', np.int64(1)),
#  ('ahora nunca alcé', np.int64(1)),
#  ('ahora nunca aproveché', np.int64(1)),
#  ('ahora pedalear colleen', np.int64(1)),
#  ('ahora prometía ser', np.int64(1)),
#  ('ahora pudo reconocer', np.int64(1)),
#  ('ahora que lo', np.int64(1)),
#  ('ahora que yo', np.int64(1)),
#  ('ahora qué hago', np.int64(1)),
#  ('ahora reconocía como', np.int64(1)),
#  ('ahora se caían', np.int64(1)),
#  ('ahora sin nieve', np.int64(1)),
#  ('ahora soy su', np.int64(1)),
#  ('ahora tratamos de', np.int64(1)),
#  ('ahora tuviera suerte', np.int64(1)),
#  ('ahora vamos los', np.int64(1)),
#  ('ahora vivo más', np.int64(1)),
#  ('ahora vivían en', np.int64(1)),
#  ('ahora ya no', np.int64(2)),
#  ('ahora yacía en', np.int64(1)),
#  ('ahora yo era', np.int64(1)),
#  ('ahora yo estaba', np.int64(1)),
#  ('ahora yo misma', np.int64(1)),
#  ('ahorros préstamos ayuda', np.int64(1)),
#  ('ahorros venía con', np.int64(1)),
#  ('ahí al poco', np.int64(1)),
#  ('ahí alguien podrá', np.int64(1)),
#  ('ahí aprendí que', np.int64(1)),
#  ('ahí así es', np.int64(1)),
#  ('ahí de inmediato', np.int64(1)),
#  ('ahí debe haber', np.int64(1)),
#  ('ahí desaparecía mi', np.int64(1)),
#  ('ahí en adelante', np.int64(1)),
#  ('ahí entendí realmente', np.int64(1)),
#  ('ahí era el', np.int64(1)),
#  ('ahí es maravillosa', np.int64(1)),
#  ('ahí estaba la', np.int64(1)),
#  ('ahí estaba mi', np.int64(1)),
#  ('ahí estaba su', np.int64(1)),
#  ('ahí estaba yo', np.int64(1)),
#  ('ahí estaban cuando', np.int64(1)),
#  ('ahí estudia daniela', np.int64(1)),
#  ('ahí finalmente pudieron', np.int64(1)),
#  ('ahí había un', np.int64(1)),
#  ('ahí instalada en', np.int64(1)),
#  ('ahí me relajaba', np.int64(1)),
#  ('ahí mi participación', np.int64(1)),
#  ('ahí mis amigos', np.int64(1)),
#  ('ahí no solamente', np.int64(1)),
#  ('ahí nos enteramos', np.int64(1)),
#  ('ahí pero sabía', np.int64(1)),
#  ('ahí podemos usar', np.int64(1)),
#  ('ahí pudo verla', np.int64(1)),
#  ('ahí que por', np.int64(1)),
#  ('ahí qué tonta', np.int64(1)),
#  ('ahí se encontró', np.int64(1)),
#  ('ahí si que', np.int64(1)),
#  ('ahí siempre estaba', np.int64(1)),
#  ('ahí sin hacer', np.int64(1)),
#  ('ahí tendría tiempo', np.int64(1)),
#  ('ahí tirada sobre', np.int64(1)),
#  ('ahí yo recibía', np.int64(1)),
#  ('aire al principio', np.int64(1)),
#  ('aire exterior incluso', np.int64(1)),
#  ('aire libre tendremos', np.int64(1)),
#  ('aire que le', np.int64(1)),
#  ('aire tuvieron que', np.int64(1)),
#  ('ajeno desconocido me', np.int64(1)),
#  ('ajeno sólo la', np.int64(1)),
#  ('ajenos mis preocupaciones', np.int64(1)),
#  ('ajetreada para leonor', np.int64(1)),
#  ('ajetreo anterior al', np.int64(1)),
#  ('ajetreo de los', np.int64(1)),
#  ('ajetreo los juegos', np.int64(1)),
#  ('ajustes lo único', np.int64(1)),
#  ('ajustes me dijo', np.int64(1)),
#  ('al abandonar el', np.int64(1)),
#  ('al abrir la', np.int64(1)),
#  ('al abuelo que', np.int64(1)),
#  ('al acercarse el', np.int64(1)),
#  ('al acercarse se', np.int64(1)),
#  ('al acostarme me', np.int64(1)),
#  ('al aire libre', np.int64(1)),
#  ('al aire tuvieron', np.int64(1)),
#  ('al alivio ya', np.int64(1)),
#  ('al alumno se', np.int64(1)),
#  ('al anciano que', np.int64(1)),
#  ('al andén un', np.int64(1)),
#  ('al atardecer ir', np.int64(1)),
#  ('al auto me', np.int64(1)),
#  ('al auto no', np.int64(1)),
#  ('al baño en', np.int64(1)),
#  ('al baño sola', np.int64(1)),
#  ('al borde de', np.int64(1)),
#  ('al cabo de', np.int64(1)),
#  ('al cabo el', np.int64(1)),
#  ('al campo paseos', np.int64(1)),
#  ('al cargar el', np.int64(1)),
#  ('al cargar las', np.int64(1)),
#  ('al cariño consideración', np.int64(1)),
#  ('al carro donde', np.int64(1)),
#  ('al celular del', np.int64(1)),
#  ('al centro de', np.int64(1)),
#  ('al centro médico', np.int64(1)),
#  ('al cien por', np.int64(1)),
#  ('al cine de', np.int64(1)),
#  ('al colegio la', np.int64(1)),
#  ('al colegio san', np.int64(1)),
#  ('al comedor cuando', np.int64(1)),
#  ('al comedor donde', np.int64(1)),
#  ('al comedor me', np.int64(1)),
#  ('al contrario he', np.int64(1)),
#  ('al costado izquierdo', np.int64(1)),
#  ('al cruzar de', np.int64(3)),
#  ('al cual yo', np.int64(1)),
#  ('al cuarto piso', np.int64(2)),
#  ('al cuidado de', np.int64(2)),
#  ('al cumplirse cinco', np.int64(1)),
#  ('al cumplirse un', np.int64(1)),
#  ('al dar el', np.int64(1)),
#  ('al darme cuenta', np.int64(1)),
#  ('al darse cuenta', np.int64(1)),
#  ('al de los', np.int64(1)),
#  ('al de un', np.int64(1)),
#  ('al descubierto parte', np.int64(1)),
#  ('al despedirse creo', np.int64(1)),
#  ('al despertar esperaba', np.int64(1)),
#  ('al dirigirnos al', np.int64(1)),
#  ('al dirigirse hacia', np.int64(1)),
#  ('al disco que', np.int64(1)),
#  ('al doblar por', np.int64(1)),
#  ('al doctor esquenazi', np.int64(1)),
#  ('al doctor jorge', np.int64(1)),
#  ('al doctor vergara', np.int64(3)),
#  ('al día en', np.int64(1)),
#  ('al día se', np.int64(1)),
#  ('al día siguiente', np.int64(11)),
#  ('al edificio de', np.int64(1)),
#  ('al empeño en', np.int64(1)),
#  ('al encargado de', np.int64(1)),
#  ('al enterarse del', np.int64(1)),
#  ('al entrar comprobé', np.int64(1)),
#  ('al entrar en', np.int64(1)),
#  ('al entrar la', np.int64(1)),
#  ('al entrar mi', np.int64(1)),
#  ('al escenario aumentaban', np.int64(1)),
#  ('al escenario decir', np.int64(1)),
#  ('al escenario en', np.int64(1)),
#  ('al escenario nos', np.int64(1)),
#  ('al escuchar mis', np.int64(1)),
#  ('al estadio español', np.int64(1)),
#  ('al estadio nacional', np.int64(1)),
#  ('al estar en', np.int64(1)),
#  ('al estar yo', np.int64(1)),
#  ('al extremo de', np.int64(1)),
#  ('al fin al', np.int64(1)),
#  ('al fin encontramos', np.int64(1)),
#  ('al fin no', np.int64(1)),
#  ('al final de', np.int64(1)),
#  ('al final del', np.int64(2)),
#  ('al final no', np.int64(1)),
#  ('al final separado', np.int64(1)),
#  ('al finalizar el', np.int64(1)),
#  ('al finalizar las', np.int64(1)),
#  ('al fondo del', np.int64(1)),
#  ('al funcionario del', np.int64(1)),
#  ('al gimnasio de', np.int64(1)),
#  ('al guardia que', np.int64(1)),
#  ('al hombre para', np.int64(1)),
#  ('al hombro caminamos', np.int64(1)),
#  ('al hospital celebraba', np.int64(1)),
#  ('al hospital clínico', np.int64(1)),
#  ('al hospital con', np.int64(1)),
#  ('al hospital de', np.int64(2)),
#  ('al hospital fusat', np.int64(2)),
#  ('al hospital lo', np.int64(1)),
#  ('al hospital por', np.int64(1)),
#  ('al hospital qué', np.int64(1)),
#  ('al hospital sin', np.int64(1)),
#  ('al hospital sólo', np.int64(1)),
#  ('al hospital también', np.int64(1)),
#  ('al hospital uc', np.int64(1)),
#  ('al hotel nos', np.int64(1)),
#  ('al igual que', np.int64(6)),
#  ('al instituto además', np.int64(1)),
#  ('al instituto por', np.int64(1)),
#  ('al instituto tantas', np.int64(1)),
#  ('al instituto todo', np.int64(1)),
#  ('al interior era', np.int64(1)),
#  ('al lado afuera', np.int64(1)),
#  ('al lado de', np.int64(2)),
#  ('al leer deduje', np.int64(1)),
#  ('al leer el', np.int64(1)),
#  ('al llegar al', np.int64(5)),
#  ('al llegar alguien', np.int64(1)),
#  ('al llegar arriba', np.int64(1)),
#  ('al llegar donde', np.int64(1)),
#  ('al llegar filadelfia', np.int64(1)),
#  ('al llegar mi', np.int64(2)),
#  ('al llegar mis', np.int64(1)),
#  ('al llegar moss', np.int64(1)),
#  ('al llegar pude', np.int64(1)),
#  ('al marcar minutos', np.int64(1)),
#  ('al menos hubiese', np.int64(1)),
#  ('al mes se', np.int64(1)),
#  ('al metro donde', np.int64(1)),
#  ('al metro tampoco', np.int64(1)),
#  ('al mismo tiempo', np.int64(1)),
#  ('al momento del', np.int64(1)),
#  ('al moss rehab', np.int64(1)),
#  ('al museo de', np.int64(1)),
#  ('al máximo aunque', np.int64(1)),
#  ('al máximo con', np.int64(1)),
#  ('al máximo maría', np.int64(1)),
#  ('al máximo para', np.int64(1)),
#  ('al máximo pero', np.int64(2)),
#  ('al mérito galardón', np.int64(1)),
#  ('al no haber', np.int64(1)),
#  ('al no tener', np.int64(2)),
#  ('al notar mi', np.int64(1)),
#  ('al número de', np.int64(1)),
#  ('al otro hasta', np.int64(1)),
#  ('al otro me', np.int64(1)),
#  ('al pabellón para', np.int64(1)),
#  ('al pabellón pude', np.int64(1)),
#  ('al parecer todo', np.int64(1)),
#  ('al parto cuando', np.int64(1)),
#  ('al parto cómo', np.int64(1)),
#  ('al parto estoy', np.int64(1)),
#  ('al pasar algunas', np.int64(1)),
#  ('al pasar más', np.int64(1)),
#  ('al pasar permanecía', np.int64(1)),
#  ('al pasar por', np.int64(1)),
#  ('al pedal correspondiente', np.int64(1)),
#  ('al personal de', np.int64(1)),
#  ('al piso de', np.int64(1)),
#  ('al poco rato', np.int64(1)),
#  ('al poco tiempo', np.int64(1)),
#  ('al poder de', np.int64(1)),
#  ('al primer piso', np.int64(1)),
#  ('al principio agradecí', np.int64(1)),
#  ('al principio era', np.int64(1)),
#  ('al principio hasta', np.int64(1)),
#  ('al principio me', np.int64(2)),
#  ('al principio mis', np.int64(1)),
#  ('al principio no', np.int64(1)),
#  ('al principio por', np.int64(1)),
#  ('al punto de', np.int64(1)),
#  ('al punto que', np.int64(1)),
#  ('al que debe', np.int64(1)),
#  ('al que sería', np.int64(1)),
#  ('al que un', np.int64(1)),
#  ('al que ustedes', np.int64(1)),
#  ('al quedarnos solos', np.int64(1)),
#  ('al quirófano ahí', np.int64(1)),
#  ('al quirófano me', np.int64(1)),
#  ('al quirófano significaba', np.int64(1)),
#  ('al rato dejó', np.int64(1)),
#  ('al rato volvió', np.int64(3)),
#  ('al rebelde volver', np.int64(1)),
#  ('al recordar esa', np.int64(1)),
#  ('al regalo lo', np.int64(1)),
#  ('al regreso nos', np.int64(1)),
#  ('al relajar se', np.int64(1)),
#  ('al respecto lo', np.int64(1)),
#  ('al resto de', np.int64(2)),
#  ('al resto del', np.int64(1)),
#  ('al revés porque', np.int64(1)),
#  ('al saber de', np.int64(1)),
#  ('al saber que', np.int64(1)),
#  ('al sacarla hacia', np.int64(1)),
#  ('al sacrificio de', np.int64(1)),
#  ('al salir de', np.int64(2)),
#  ('al segundo piso', np.int64(2)),
#  ('al ser llamados', np.int64(1)),
#  ('al ser sacada', np.int64(1)),
#  ('al ser trasladada', np.int64(1)),
#  ('al servicio de', np.int64(1)),
#  ('al siguiente carro', np.int64(1)),
#  ('al son de', np.int64(1)),
#  ('al suyo es', np.int64(1)),
#  ('al televisor me', np.int64(1)),
#  ('al tensar dicho', np.int64(1)),
#  ('al tercer vagón', np.int64(1)),
#  ('al tomar el', np.int64(1)),
#  ('al tope de', np.int64(1)),
#  ('al traqueteo sólo', np.int64(1)),
#  ('al traspasar la', np.int64(1)),
#  ('al tren sonó', np.int64(1)),
#  ('al tren tuvieron', np.int64(1)),
#  ('al término de', np.int64(2)),
#  ('al típico ajetreo', np.int64(1)),
#  ('al unísono franz', np.int64(1)),
#  ('al unísono sorpresa', np.int64(1)),
#  ('al urdir los', np.int64(1)),
#  ('al vagón quizás', np.int64(1)),
#  ('al ver el', np.int64(1)),
#  ('al ver la', np.int64(1)),
#  ('al ver nuestro', np.int64(1)),
#  ('al ver sus', np.int64(1)),
#  ('al ver una', np.int64(1)),
#  ('al verla aún', np.int64(1)),
#  ('al verla ella', np.int64(1)),
#  ('al verla muchos', np.int64(1)),
#  ('al verla padecer', np.int64(1)),
#  ('al verlo acercarse', np.int64(1)),
#  ('al verlos no', np.int64(2)),
#  ('al verlos otra', np.int64(1)),
#  ('al verme el', np.int64(1)),
#  ('al verme sonrió', np.int64(1)),
#  ('al viaje no', np.int64(1)),
#  ('al volante atravesamos', np.int64(1)),
#  ('al volante pero', np.int64(1)),
#  ('al volver al', np.int64(1)),
#  ('al volver sentir', np.int64(1)),
#  ('alarma contra incendios', np.int64(1)),
#  ('alarma es un', np.int64(1)),
#  ('alarma la casa', np.int64(1)),
#  ('alarma la miraron', np.int64(1)),
#  ('alarma nada dani', np.int64(1)),
#  ('alarma pero no', np.int64(1)),
#  ('alarma por qué', np.int64(1)),
#  ('albert einstein moss', np.int64(1)),
#  ('alberto esquenazi conocía', np.int64(1)),
#  ('alberto esquenazi di', np.int64(1)),
#  ('alberto esquenazi fisiatra', np.int64(1)),
#  ('alberto villarroel amigo', np.int64(1)),
#  ('alcalde de santiago', np.int64(1)),
#  ('alcance para el', np.int64(1)),
#  ('alcancé recorrer ni', np.int64(1)),
#  ('alcanzaban verse subió', np.int64(1)),
#  ('alcanzadas antes de', np.int64(1)),
#  ('alcanzado cada cosa', np.int64(1)),
#  ('alcanzado mi sueño', np.int64(1)),
#  ('alcanzar celebrar el', np.int64(1)),
#  ('alcanzar metas más', np.int64(1)),
#  ('alcanzar mis metas', np.int64(1)),
#  ('alcanzar pero nada', np.int64(1)),
#  ('alcanzaron tener todo', np.int64(1)),
#  ('alcohol drogas el', np.int64(1)),
#  ('alcohol ni consumía', np.int64(1)),
#  ('alcé mi brazo', np.int64(1)),
#  ('alcé mi pie', np.int64(1)),
#  ('alegraba estar de', np.int64(1)),
#  ('alegrarme somos cinco', np.int64(1)),
#  ('alegraron los muros', np.int64(1)),
#  ('alegre conversación le', np.int64(1)),
#  ('alegre me despedí', np.int64(1)),
#  ('alegre no supe', np.int64(1)),
#  ('alegre plena sí', np.int64(1)),
#  ('alegremente cecilia su', np.int64(1)),
#  ('alegremente con algún', np.int64(1)),
#  ('alegremente varios kinesiólogos', np.int64(1)),
#  ('alegres colores el', np.int64(1)),
#  ('alegres el viaje', np.int64(1)),
#  ('alegres entusiasmados me', np.int64(1)),
#  ('alegres entusiastas quienes', np.int64(1)),
#  ('alegres los niños', np.int64(1)),
#  ('alegré de sentirlo', np.int64(1)),
#  ('alegré mucho de', np.int64(1)),
#  ('alegría cada una', np.int64(1)),
#  ('alegría cuando entendí', np.int64(1)),
#  ('alegría cuando una', np.int64(1)),
#  ('alegría de mis', np.int64(1)),
#  ('alegría de ver', np.int64(1)),
#  ('alegría la habitación', np.int64(1)),
#  ('alegría luego el', np.int64(1)),
#  ('alegría no menor', np.int64(1)),
#  ('alegría qué avance', np.int64(1)),
#  ('alegría risas mi', np.int64(1)),
#  ('alegría se hablaba', np.int64(1)),
#  ('alegría yo sabía', np.int64(1)),
#  ('alegría íbamos en', np.int64(1)),
#  ('alegrías debo reconocer', np.int64(1)),
#  ('alegrías desde que', np.int64(1)),
#  ('alegrías más grandes', np.int64(1)),
#  ('alegró con mi', np.int64(1)),
#  ('alegró me dio', np.int64(1)),
#  ('alegró no sólo', np.int64(1)),
#  ('alejandro felipe juan', np.int64(1)),
#  ('alejandro josé luis', np.int64(1)),
#  ('alejandro juampi diego', np.int64(1)),
#  ('alejandro uno de', np.int64(1)),
#  ('alejarme de mi', np.int64(1)),
#  ('alejarse la ambulancia', np.int64(1)),
#  ('alejarse por suerte', np.int64(1)),
#  ('alejarse salvo el', np.int64(1)),
#  ('alejándola de la', np.int64(1)),
#  ('alejó el susto', np.int64(1)),
#  ('alejó los del', np.int64(1)),
#  ('alejó por primera', np.int64(1)),
#  ('alejó volvió el', np.int64(1)),
#  ('alejó yo recé', np.int64(1)),
#  ('alfiler en mi', np.int64(1)),
#  ('algo abrigador aconsejó', np.int64(1)),
#  ('algo ahora pudo', np.int64(1)),
#  ('algo al acostarme', np.int64(1)),
#  ('algo así dios', np.int64(1)),
#  ('algo así fue', np.int64(1)),
#  ('algo así lloré', np.int64(1)),
#  ('algo así me', np.int64(1)),
#  ('algo así que', np.int64(1)),
#  ('algo así sería', np.int64(1)),
#  ('algo bueno que', np.int64(1)),
#  ('algo comprado en', np.int64(1)),
#  ('algo común después', np.int64(1)),
#  ('algo con las', np.int64(1)),
#  ('algo con ricardo', np.int64(1)),
#  ('algo concreto en', np.int64(1)),
#  ('algo de aire', np.int64(1)),
#  ('algo de lo', np.int64(1)),
#  ('algo debía hacer', np.int64(1)),
#  ('algo delicioso éramos', np.int64(1)),
#  ('algo dijo la', np.int64(1)),
#  ('algo divertido alguna', np.int64(1)),
#  ('algo en lo', np.int64(1)),
#  ('algo en mi', np.int64(1)),
#  ('algo en su', np.int64(1)),
#  ('algo entonces sabrás', np.int64(1)),
#  ('algo esotéricas en', np.int64(1)),
#  ('algo faltaba al', np.int64(1)),
#  ('algo familiar me', np.int64(1)),
#  ('algo fijé más', np.int64(1)),
#  ('algo hecho por', np.int64(1)),
#  ('algo hoy tengo', np.int64(1)),
#  ('algo húmedo en', np.int64(1)),
#  ('algo idéntico las', np.int64(1)),
#  ('algo imprudente incluso', np.int64(1)),
#  ('algo inquieta sobre', np.int64(1)),
#  ('algo insegura me', np.int64(1)),
#  ('algo la paula', np.int64(1)),
#  ('algo la simple', np.int64(1)),
#  ('algo las piernas', np.int64(1)),
#  ('algo lo que', np.int64(1)),
#  ('algo me afirmé', np.int64(1)),
#  ('algo me encanta', np.int64(1)),
#  ('algo mejor acepté', np.int64(1)),
#  ('algo muy gracioso', np.int64(1)),
#  ('algo muy importante', np.int64(2)),
#  ('algo muy lindo', np.int64(1)),
#  ('algo más me', np.int64(1)),
#  ('algo no estaba', np.int64(1)),
#  ('algo no te', np.int64(1)),
#  ('algo nuevo aunque', np.int64(1)),
#  ('algo nuevo digno', np.int64(1)),
#  ('algo nuevo me', np.int64(1)),
#  ('algo nuevo más', np.int64(1)),
#  ('algo para que', np.int64(1)),
#  ('algo pensé en', np.int64(1)),
#  ('algo productivo tengo', np.int64(1)),
#  ('algo que hacía', np.int64(1)),
#  ('algo que me', np.int64(4)),
#  ('algo que nunca', np.int64(1)),
#  ...]

# %% [markdown]
# #### 1.2. Train by making a dictionary based on n-Grams:

# %%
n = 3                                                           # Can be changed to a number equal or larger than 2.
n_min = n
n_max = n
n_gram_type = 'word'
vectorizer = CountVectorizer(ngram_range=(n_min,n_max), analyzer = n_gram_type)

# %%
nltk.download('punkt_tab')

n_grams = vectorizer.fit([corpus_limpio]).get_feature_names_out()           # A list of n-Grams.
my_dict = {}
for a_gram in n_grams:
    words = nltk.word_tokenize(a_gram)
    a_nm1_gram = ' '.join(words[0:n-1])  # El (n-1)-grama
    next_word = words[-1]               # Palabra siguiente
    if a_nm1_gram not in my_dict:
        my_dict[a_nm1_gram] = [next_word]
    else:
        my_dict[a_nm1_gram].append(next_word)
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.

# %%
# Ver parte del diccionario
for k in list(my_dict)[:10]:
    print(f"{k} ➜ {my_dict[k]}")
# Out:
# 11 de ➜ ['agosto']
# 17 de ➜ ['diciembre']
# 1999 entré ➜ ['estudiar']
# 2002 empezó ➜ ['temprano']
# 2002 fue ➜ ['especialmente', 'un']
# 2003 antes ➜ ['del']
# 2003 estaba ➜ ['programada']
# 2003 llegué ➜ ['por']
# 2003 mis ➜ ['papás']
# 2003 sino ➜ ['también']

# %%
# View the dictionary.
my_dict
# Out:
# {'11 de': ['agosto'],
#  '17 de': ['diciembre'],
#  '1999 entré': ['estudiar'],
#  '2002 empezó': ['temprano'],
#  '2002 fue': ['especialmente', 'un'],
#  '2003 antes': ['del'],
#  '2003 estaba': ['programada'],
#  '2003 llegué': ['por'],
#  '2003 mis': ['papás'],
#  '2003 sino': ['también'],
#  '2004 daniela': ['garcía'],
#  '2004 estas': ['fotos'],
#  '2004 fui': ['nuevamente'],
#  '2014 2004': ['daniela'],
#  '2014 penguin': ['random'],
#  '21 22': ['de'],
#  '22 años': ['no'],
#  '22 de': ['noviembre'],
#  '280 piso': ['santiago'],
#  '30 de': ['octubre'],
#  '50 con': ['vagones'],
#  '9789562584005 conversión': ['formato'],
#  'abajo como': ['siempre'],
#  'abajo tratando': ['de'],
#  'abandonaban incluso': ['intenté'],
#  'abandonaban jamás': ['iba'],
#  'abandonando mi': ['cuerpo'],
#  'abandonar el': ['proscenio'],
#  'abandonar la': ['casa'],
#  'abandonaría la': ['terapia'],
#  'abandonó la': ['uci'],
#  'abarrotada no': ['dejaba'],
#  'abdominales en': ['distintas'],
#  'abdominales levantar': ['algunos'],
#  'abierta lo': ['que'],
#  'abiertas para': ['permitir'],
#  'abismante cómo': ['iban'],
#  'abogado josé': ['miguel'],
#  'abogados los': ['de'],
#  'abracé con': ['toda'],
#  'abracé en': ['el'],
#  'abrazaba sin': ['parar'],
#  'abrazaban tratando': ['de'],
#  'abrazamos me': ['pude', 'sentí'],
#  'abrazara me': ['dijera'],
#  'abrazarnos con': ['mi'],
#  'abrazaron también': ['había'],
#  'abrazos nunca': ['había'],
#  'abrazó fuerte': ['los'],
#  'abre el': ['gancho'],
#  'abriendo un': ['mundo'],
#  'abrigada mis': ['papás'],
#  'abrigador aconsejó': ['leonor'],
#  'abrigara porque': ['íbamos'],
#  'abril de': ['modo'],
#  'abrir la': ['puerta'],
#  'abrir las': ['cortinas', 'ventanas'],
#  'abrir los': ['distintos', 'ojos'],
#  'abrir un': ['humilde'],
#  'abrirla adentro': ['sólo'],
#  'abrirla asentí': ['las'],
#  'abrirla cuando': ['ya'],
#  'abrirnos paso': ['nos'],
#  'abrirá me': ['explicó'],
#  'abrió de': ['golpe'],
#  'abrió el': ['mundo', 'refrigerador'],
#  'abrió la': ['puerta'],
#  'abrió otra': ['vez'],
#  'abrió su': ['maleta'],
#  'abro vuelvo': ['sentir'],
#  'abruma sólo': ['dan'],
#  'abrí con': ['cuidado'],
#  'abrí el': ['clóset'],
#  'abrí los': ['ojos'],
#  'abría era': ['ricardo'],
#  'abría los': ['ojos'],
#  'abríamos nuestro': ['consultorio'],
#  'absorber en': ['muy'],
#  'absorta en': ['mi'],
#  'abuela materna': ['que'],
#  'abuelita ah': ['no'],
#  'abuelita apretó': ['usted'],
#  'abuelita desesperadas': ['tratando'],
#  'abuelita ellos': ['no'],
#  'abuelita en': ['uno'],
#  'abuelita la': ['cati', 'puerta'],
#  'abuelita llevó': ['la'],
#  'abuelita materna': ['qué'],
#  'abuelita me': ['voy'],
#  'abuelita que': ['nos'],
#  'abuelita te': ['voy'],
#  'abuelita trataba': ['de'],
#  'abuelita uno': ['de'],
#  'abuelita yo': ['salimos'],
#  'abuelo paterno': ['los'],
#  'abuelo que': ['te'],
#  'aburrido lejos': ['de'],
#  'académicos de': ['todo'],
#  'acarició la': ['cabeza'],
#  'acarrearon la': ['enorme'],
#  'acaso no': ['saben'],
#  'acaso tendría': ['que'],
#  'accedió llevarme': ['hasta'],
#  'acceso atochado': ['de'],
#  'accidentada en': ['la'],
#  'accidentada los': ['muchachos'],
#  'accidentada un': ['grupo'],
#  'accidente así': ['aunque'],
#  'accidente con': ['el'],
#  'accidente cuáles': ['actividades'],
#  'accidente de': ['daniela', 'mi', 'pronto'],
#  'accidente despertó': ['el'],
#  'accidente dónde': ['estoy'],
#  'accidente el': ['accidente', 'rescate', 'segundo'],
#  'accidente en': ['el', 'una'],
#  'accidente era': ['increíble'],
#  'accidente es': ['decir', 'rico'],
#  'accidente exclamó': ['no'],
#  'accidente formaran': ['parte'],
#  'accidente fue': ['causado'],
#  'accidente gasté': ['mis'],
#  'accidente había': ['llegado'],
#  'accidente he': ['recibido'],
#  'accidente intentaba': ['desarrollar'],
#  'accidente la': ['felicidad', 'inmovilidad', 'locomotora', 'rehabilitación'],
#  'accidente lloré': ['lloré'],
#  'accidente luego': ['me'],
#  'accidente mi': ['familia'],
#  'accidente no': ['estaba', 'lo', 'me'],
#  'accidente pensar': ['que'],
#  'accidente pero': ['jamás'],
#  'accidente poco': ['poco'],
#  'accidente por': ['favor'],
#  'accidente que': ['ellos', 'no'],
#  'accidente rafael': ['yo'],
#  'accidente razón': ['por'],
#  'accidente se': ['podría'],
#  'accidente su': ['coraje'],
#  'accidente sus': ['consecuencias'],
#  'accidente todavía': ['quiero'],
#  'accidente todo': ['podría'],
#  'accidente través': ['de'],
#  'accidente tuve': ['mucho'],
#  'accidente uno': ['de'],
#  'accidente yo': ['estaba', 'lo'],
#  'accidentes vasculares': ['encefálicos'],
#  'acciones que': ['se'],
#  'acción qué': ['quieres'],
#  'acelerador sin': ['dar'],
#  'acento tan': ['familiar'],
#  'acentuaba cada': ['vez'],
#  'aceptación la': ['motivadora'],
#  'aceptación una': ['semana'],
#  'aceptar fue': ['la'],
#  'aceptar lo': ['ocurrido'],
#  'aceptar mi': ['respuesta'],
#  'aceptar que': ['ahora'],
#  'aceptar ser': ['reserva'],
#  'aceptarlo mis': ['papás'],
#  'aceptarlos edición': ['en'],
#  'aceptarlos mí': ['también'],
#  'acepté la': ['propuesta'],
#  'aceptó una': ['pastilla'],
#  'aceptó ya': ['me'],
#  'acercaba al': ['ver'],
#  'acercaba justo': ['por'],
#  'acercaba la': ['fecha', 'navidad'],
#  'acercaba mí': ['sin'],
#  'acercaba se': ['fueron'],
#  'acercaba un': ['tren'],
#  'acercaba yo': ['no'],
#  'acercaban los': ['caballos'],
#  'acercado mucho': ['más'],
#  'acercado mí': ['permaneció'],
#  'acercando la': ['fecha'],
#  'acercaron saludarme': ['con'],
#  'acercarse el': ['día'],
#  'acercarse le': ['dije'],
#  'acercarse me': ['preguntó'],
#  'acercarse saltando': ['de'],
#  'acercarse se': ['percató'],
#  'acercarse una': ['joven'],
#  'acercábamos yo': ['trataba'],
#  'acercó al': ['hombre'],
#  'acercó con': ['los'],
#  'acercó en': ['un'],
#  'acercó eres': ['tú'],
#  'acercó marco': ['me'],
#  'acercó me': ['acarició', 'hizo', 'preguntó'],
#  'acercó no': ['sé'],
#  'acercó qué': ['hacen'],
#  'acercó rafael': ['araneda'],
#  'acercó tomándome': ['de'],
#  'acercó un': ['carabinero'],
#  'acercó una': ['mujer'],
#  'acercó vio': ['que'],
#  'acerqué algo': ['insegura'],
#  'acerqué ellos': ['ves'],
#  'acerqué pude': ['ver'],
#  'aclamaba reconoció': ['al'],
#  'aclarar que': ['no'],
#  'acogedor pero': ['me'],
#  'acogedora el': ['hecho'],
#  'acogedora todo': ['estaba'],
#  'acogida la': ['gente'],
#  'acogida que': ['incluso'],
#  'acomodaba por': ['su'],
#  'acomodaban alegre': ['me'],
#  'acomodándose muchos': ['estudiantes'],
#  'acompañaba ese': ['día'],
#  'acompañaba julie': ['como'],
#  'acompañaba la': ['salida'],
#  'acompañaban incluso': ['dormían'],
#  'acompañaban mis': ['familiares'],
#  'acompañada por': ['algún', 'mis'],
#  'acompañada siempre': ['por'],
#  'acompañado moss': ['ahora'],
#  'acompañado por': ['josé'],
#  'acompañados por': ['los'],
#  'acompañamiento podía': ['ser'],
#  'acompañando por': ['algunas'],
#  'acompañando sus': ['nietos'],
#  'acompañar en': ['todo'],
#  'acompañar la': ['caro'],
#  'acompañara compraba': ['el'],
#  'acompañara después': ['llegaron'],
#  'acompañara en': ['el'],
#  'acompañarlos rancagua': ['leonor'],
#  'acompañarme durante': ['todo'],
#  'acompañaron guardar': ['mi'],
#  'acompañaron mi': ['hija'],
#  'acompañaron mis': ['papás'],
#  'acompañarían por': ['algún'],
#  'acompaño me': ['contestó'],
#  'acompañándome en': ['las'],
#  'acompañó buscar': ['mi'],
#  'acompañó hasta': ['el', 'santiago'],
#  'acompañó toda': ['la'],
#  'aconsejaban para': ['tratar'],
#  'aconsejó leonor': ['daniela'],
#  'acontecía por': ['un'],
#  'acontezca algo': ['terrible'],
#  'acordaba bien': ['qué'],
#  'acordaba de': ['un'],
#  'acordaban de': ['mí'],
#  'acordado de': ['mí'],
#  'acordamos que': ['de'],
#  'acordarme de': ['la'],
#  'acordé de': ['mi', 'una'],
#  'acordó de': ['la'],
#  'acostada sin': ['moverme'],
#  'acostada sobre': ['pequeñas'],
#  'acostar esperando': ['que'],
#  'acostarme me': ['costó'],
#  'acostumbra que': ['los'],
#  'acostumbraba las': ['manos'],
#  'acostumbraba no': ['ver'],
#  'acostumbrada familiarizada': ['con'],
#  'acostumbrada levantarme': ['entre'],
#  'acostumbrada tener': ['los'],
#  'acostumbrado al': ['traqueteo'],
#  'acostumbrados cargar': ['mi'],
#  'acostumbrando ellos': ['lo'],
#  'acostumbrando las': ['tinieblas'],
#  'acostumbrarme la': ['rodilla'],
#  'acostumbrarme nuevamente': ['mi'],
#  'acostumbrarse una': ['apariencia'],
#  'acostumbrarse usar': ['prótesis'],
#  'acreditaba apta': ['para'],
#  'actitud de': ['don'],
#  'actitud respetuosa': ['el'],
#  'activada la': ['palanca'],
#  'activadas por': ['mi'],
#  'activar cada': ['electrodo'],
#  'actives un': ['electrodo'],
#  'actividad favorita': ['ahí'],
#  'actividad física': ['desde'],
#  'actividad que': ['había'],
#  'actividad voluntaria': ['que'],
#  'actividades de': ['rehabilitación', 'un'],
#  'actividades echaba': ['de'],
#  'actividades iría': ['de'],
#  'actividades que': ['me', 'nos'],
#  'actividades universitarias': ['me'],
#  'activó la': ['alarma'],
#  'actores prácticamente': ['podíamos'],
#  'actuado de': ['ese'],
#  'actual me': ['decidí'],
#  'acuarela con': ['flores'],
#  'acuario con': ['pequeños'],
#  'acudir clases': ['en'],
#  'acuerdo de': ['su'],
#  'acuerdo extrajudicial': ['después'],
#  'acuerdo nada': ['de'],
#  'acuerdo que': ['me'],
#  'acumulaban tarjetas': ['regalos'],
#  'acumuladas en': ['la'],
#  'acusar al': ['abuelo'],
#  'acuérdate de': ['que'],
#  'acá llamó': ['alejandro'],
#  'acá me': ['dije'],
#  'acá no': ['bien'],
#  'adaptaciones mi': ['ropa'],
#  'adaptaciones posibles': ['le'],
#  'adaptaciones que': ['creía'],
#  'adaptado con': ['rampas'],
#  'adaptado para': ['que'],
#  'adaptarnos los': ['cambios'],
#  'adaptarse los': ['cambios'],
#  'adaptaría ellas': ['otra'],
#  'adaptó un': ['baño'],
#  'adaptó unas': ['tijeras'],
#  'adecuado para': ['mi', 'una'],
#  'adelantado organizada': ['por'],
#  'adelante al': ['carro', 'cumplirse', 'llegar'],
#  'adelante aunque': ['esa'],
#  'adelante durante': ['mi'],
#  'adelante el': ['dolor'],
#  'adelante eso': ['me'],
#  'adelante estaba': ['el'],
#  'adelante la': ['gente', 'verdad'],
#  'adelante las': ['dos'],
#  'adelante le': ['contesté'],
#  'adelante lo': ['entienda'],
#  'adelante me': ['fijé'],
#  'adelante mi': ['último'],
#  'adelante nunca': ['les'],
#  'adelante pensé': ['que'],
#  'adelante pero': ['ya'],
#  'adelante podría': ['ir'],
#  'adelante sería': ['suficiente'],
#  'adelante serían': ['más'],
#  'adelante tener': ['una'],
#  'adelantos antes': ['de'],
#  'además acarrearon': ['la'],
#  'además compartir': ['con'],
#  'además de': ['asegurarse', 'eso', 'estar', 'la', 'las'],
#  'además debía': ['preparar'],
#  'además en': ['el', 'esa'],
#  'además era': ['un'],
#  'además eran': ['muy'],
#  'además estaba': ['muy'],
#  'además extrañaba': ['los'],
#  'además la': ['estética', 'integración'],
#  'además le': ['produjo'],
#  'además me': ['dolía'],
#  'además serviría': ['de'],
#  'además sería': ['únicamente'],
#  'además tenía': ['contactos'],
#  'además todavía': ['tenía'],
#  'además ya': ['sólo'],
#  'adentro daniela': ['estaba'],
#  'adentro fui': ['llevada'],
#  'adentro seguro': ['que'],
#  'adentro sólo': ['había'],
#  'adentros tenemos': ['tiempo'],
#  'adivinaba el': ['cariño'],
#  'adiviné más': ['tranquilo'],
#  'administrando muchos': ['medicamentos'],
#  'administraron morfina': ['pero'],
#  'admirada de': ['que'],
#  'admitirlo pero': ['debo'],
#  'adolescencia nos': ['distanciamos'],
#  'adolfo ibáñez': ['había'],
#  'adolorida en': ['mi'],
#  'adonde me': ['lo'],
#  'adornada sólo': ['por'],
#  'adornos regalos': ['recibidos'],
#  'adosar las': ['sillas'],
#  'adquirir un': ['scooter'],
#  'adrenalina corría': ['por'],
#  'adulta había': ['cerrado'],
#  'adversidad pronunció': ['otra'],
#  'advertencias del': ['papá'],
#  'advertido era': ['que'],
#  'advertido que': ['tendría'],
#  'advertir el': ['aspecto'],
#  'advertí la': ['preocupación'],
#  'advirtiéndome que': ['no'],
#  'advirtió que': ['sus'],
#  'adónde cuándo': ['me'],
#  'aeropuerto me': ['despedí', 'pareció'],
#  'aeropuerto nos': ['ayudó'],
#  'afanaba en': ['el', 'la'],
#  'afectado salía': ['frecuentemente'],
#  'afectados especialmente': ['el'],
#  'afectados habían': ['quedado'],
#  'afectan nunca': ['pensamos'],
#  'afectar más': ['pero'],
#  'afectarme alguna': ['vez'],
#  'afectaría su': ['relación'],
#  'afecto de': ['mi'],
#  'afecto me': ['cambiaban'],
#  'afecto ricardo': ['por'],
#  'afectuosos como': ['él'],
#  'aferrada ese': ['pensamiento'],
#  'afirmando mientras': ['yo'],
#  'afirmar las': ['manos'],
#  'afirmar una': ['cuchara'],
#  'afirmé en': ['los'],
#  'aflicción creció': ['dentro'],
#  'afortunadamente mi': ['cama'],
#  'afortunadamente poco': ['poco'],
#  'afuera alguien': ['se'],
#  'afuera de': ['su'],
#  'afuera pasear': ['un'],
#  'agarre se': ['regula'],
#  'agarré la': ['mano'],
#  'agitaban en': ['la'],
#  'agitada su': ['madre'],
#  'agolparon pedirle': ['la'],
#  'agosto de': ['2003', 'modo'],
#  'agosto se': ['encontró'],
#  'agotada anunció': ['mi'],
#  'agotada como': ['cada'],
#  'agotada cómo': ['hacerlo'],
#  'agotada de': ['modo'],
#  'agotada la': ['casa'],
#  'agotada por': ['mi'],
#  'agotada sabía': ['que'],
#  'agotada se': ['sentía'],
#  'agotada todos': ['los'],
#  'agotada yo': ['empezaba'],
#  'agradable cómo': ['me'],
#  'agradable encontrarse': ['con'],
#  'agradable eso': ['me'],
#  'agradable nos': ['íbamos'],
#  'agradecer dios': ['por'],
#  'agradecer las': ['escritoras'],
#  'agradecer personalmente': ['todos'],
#  'agradecer porque': ['finalmente'],
#  'agradecer que': ['hubiese'],
#  'agradecer suficiente': ['todas'],
#  'agradecer suficientemente': ['al'],
#  'agradecerle decirle': ['cuan'],
#  'agradecerles lo': ['suficiente'],
#  'agradecerles pero': ['al'],
#  'agradecerles su': ['apoyo'],
#  'agradecida por': ['eso'],
#  'agradecida sigo': ['andando'],
#  'agradecieron los': ['médicos'],
#  'agradecimiento hacia': ['ellos', 'esas'],
#  'agradecimientos no': ['fue'],
#  'agradecimientos prólogo': ['antes'],
#  'agradecí al': ['doctor'],
#  'agradecí dios': ['que'],
#  'agradecí mil': ['veces'],
#  'agradecí su': ['lindo'],
#  'agradecí tener': ['los'],
#  'agradezco mis': ['papás'],
#  'agrado pero': ['si'],
#  'agregamos una': ['cama'],
#  'agregué cómo': ['va'],
#  'agregué estaba': ['absorta'],
#  'agregó amablemente': ['el'],
#  'agregó martín': ['la'],
#  'agregó mi': ['abuelita'],
#  'agregó mientras': ['hablaba'],
#  'agua la': ['sed'],
#  'agua lo': ['hice'],
#  'agua para': ['lavarla'],
#  'agua sobre': ['su'],
#  'agua una': ['puerta'],
#  'aguantaba tanto': ['rato'],
#  'aguantar más': ['de'],
#  'aguantara más': ['cuando'],
#  'aguanté lo': ['más'],
#  'agudizó el': ['oído'],
#  'aguja en': ['el'],
#  'aguja no': ['debe'],
#  'agujas el': ['dolor'],
#  'agujas parecían': ['tener'],
#  'agujas se': ['movían'],
#  'agujero al': ['cruzar'],
#  'agujero en': ['el'],
#  'ah bueno': ['debería'],
#  'ah no': ['entonces', 'sé'],
#  'ahora camina': ['usando'],
#  'ahora con': ['el', 'las'],
#  'ahora de': ['pie'],
#  'ahora divisé': ['josé'],
#  'ahora el': ['cuerpo'],
#  'ahora en': ['adelante', 'chile'],
#  'ahora era': ['tan'],
#  'ahora es': ['muy'],
#  'ahora estaban': ['aprendiendo'],
#  'ahora está': ['en'],
#  'ahora existen': ['unas'],
#  'ahora formalmente': ['era'],
#  'ahora fuese': ['tan'],
#  'ahora había': ['que'],
#  'ahora inexistentes': ['se'],
#  'ahora la': ['distancia', 'medicina'],
#  'ahora las': ['cosas', 'fuerzas', 'uso'],
#  'ahora lo': ['estuve'],
#  'ahora los': ['programan'],
#  'ahora me': ['doy', 'iba', 'pareció'],
#  'ahora mi': ['sueño'],
#  'ahora miraba': ['entre'],
#  'ahora nunca': ['alcé', 'aproveché'],
#  'ahora pedalear': ['colleen'],
#  'ahora prometía': ['ser'],
#  'ahora pudo': ['reconocer'],
#  'ahora que': ['lo', 'yo'],
#  'ahora qué': ['hago'],
#  'ahora reconocía': ['como'],
#  'ahora se': ['caían'],
#  'ahora sin': ['nieve'],
#  'ahora soy': ['su'],
#  'ahora tratamos': ['de'],
#  'ahora tuviera': ['suerte'],
#  'ahora vamos': ['los'],
#  'ahora vivo': ['más'],
#  'ahora vivían': ['en'],
#  'ahora ya': ['no'],
#  'ahora yacía': ['en'],
#  'ahora yo': ['era', 'estaba', 'misma'],
#  'ahorros préstamos': ['ayuda'],
#  'ahorros venía': ['con'],
#  'ahí al': ['poco'],
#  'ahí alguien': ['podrá'],
#  'ahí aprendí': ['que'],
#  'ahí así': ['es'],
#  'ahí de': ['inmediato'],
#  'ahí debe': ['haber'],
#  'ahí desaparecía': ['mi'],
#  'ahí en': ['adelante'],
#  'ahí entendí': ['realmente'],
#  'ahí era': ['el'],
#  'ahí es': ['maravillosa'],
#  'ahí estaba': ['la', 'mi', 'su', 'yo'],
#  'ahí estaban': ['cuando'],
#  'ahí estudia': ['daniela'],
#  'ahí finalmente': ['pudieron'],
#  'ahí había': ['un'],
#  'ahí instalada': ['en'],
#  'ahí me': ['relajaba'],
#  'ahí mi': ['participación'],
#  'ahí mis': ['amigos'],
#  'ahí no': ['solamente'],
#  'ahí nos': ['enteramos'],
#  'ahí pero': ['sabía'],
#  'ahí podemos': ['usar'],
#  'ahí pudo': ['verla'],
#  'ahí que': ['por'],
#  'ahí qué': ['tonta'],
#  'ahí se': ['encontró'],
#  'ahí si': ['que'],
#  'ahí siempre': ['estaba'],
#  'ahí sin': ['hacer'],
#  'ahí tendría': ['tiempo'],
#  'ahí tirada': ['sobre'],
#  'ahí yo': ['recibía'],
#  'aire al': ['principio'],
#  'aire exterior': ['incluso'],
#  'aire libre': ['tendremos'],
#  'aire que': ['le'],
#  'aire tuvieron': ['que'],
#  'ajeno desconocido': ['me'],
#  'ajeno sólo': ['la'],
#  'ajenos mis': ['preocupaciones'],
#  'ajetreada para': ['leonor'],
#  'ajetreo anterior': ['al'],
#  'ajetreo de': ['los'],
#  'ajetreo los': ['juegos'],
#  'ajustes lo': ['único'],
#  'ajustes me': ['dijo'],
#  'al abandonar': ['el'],
#  'al abrir': ['la'],
#  'al abuelo': ['que'],
#  'al acercarse': ['el', 'se'],
#  'al acostarme': ['me'],
#  'al aire': ['libre', 'tuvieron'],
#  'al alivio': ['ya'],
#  'al alumno': ['se'],
#  'al anciano': ['que'],
#  'al andén': ['un'],
#  'al atardecer': ['ir'],
#  'al auto': ['me', 'no'],
#  'al baño': ['en', 'sola'],
#  'al borde': ['de'],
#  'al cabo': ['de', 'el'],
#  'al campo': ['paseos'],
#  'al cargar': ['el', 'las'],
#  'al cariño': ['consideración'],
#  'al carro': ['donde'],
#  'al celular': ['del'],
#  'al centro': ['de', 'médico'],
#  'al cien': ['por'],
#  'al cine': ['de'],
#  'al colegio': ['la', 'san'],
#  'al comedor': ['cuando', 'donde', 'me'],
#  'al contrario': ['he'],
#  'al costado': ['izquierdo'],
#  'al cruzar': ['de'],
#  'al cual': ['yo'],
#  'al cuarto': ['piso'],
#  'al cuidado': ['de'],
#  'al cumplirse': ['cinco', 'un'],
#  'al dar': ['el'],
#  'al darme': ['cuenta'],
#  'al darse': ['cuenta'],
#  'al de': ['los', 'un'],
#  'al descubierto': ['parte'],
#  'al despedirse': ['creo'],
#  'al despertar': ['esperaba'],
#  'al dirigirnos': ['al'],
#  'al dirigirse': ['hacia'],
#  'al disco': ['que'],
#  'al doblar': ['por'],
#  'al doctor': ['esquenazi', 'jorge', 'vergara'],
#  'al día': ['en', 'se', 'siguiente'],
#  'al edificio': ['de'],
#  'al empeño': ['en'],
#  'al encargado': ['de'],
#  'al enterarse': ['del'],
#  'al entrar': ['comprobé', 'en', 'la', 'mi'],
#  'al escenario': ['aumentaban', 'decir', 'en', 'nos'],
#  'al escuchar': ['mis'],
#  'al estadio': ['español', 'nacional'],
#  'al estar': ['en', 'yo'],
#  'al extremo': ['de'],
#  'al fin': ['al', 'encontramos', 'no'],
#  'al final': ['de', 'del', 'no', 'separado'],
#  'al finalizar': ['el', 'las'],
#  'al fondo': ['del'],
#  'al funcionario': ['del'],
#  'al gimnasio': ['de'],
#  'al guardia': ['que'],
#  'al hombre': ['para'],
#  'al hombro': ['caminamos'],
#  'al hospital': ['celebraba',
#   'clínico',
#   'con',
#   'de',
#   'fusat',
#   'lo',
#   'por',
#   'qué',
#   'sin',
#   'sólo',
#   'también',
#   'uc'],
#  'al hotel': ['nos'],
#  'al igual': ['que'],
#  'al instituto': ['además', 'por', 'tantas', 'todo'],
#  'al interior': ['era'],
#  'al lado': ['afuera', 'de'],
#  'al leer': ['deduje', 'el'],
#  'al llegar': ['al',
#   'alguien',
#   'arriba',
#   'donde',
#   'filadelfia',
#   'mi',
#   'mis',
#   'moss',
#   'pude'],
#  'al marcar': ['minutos'],
#  'al menos': ['hubiese'],
#  'al mes': ['se'],
#  'al metro': ['donde', 'tampoco'],
#  'al mismo': ['tiempo'],
#  'al momento': ['del'],
#  'al moss': ['rehab'],
#  'al museo': ['de'],
#  'al máximo': ['aunque', 'con', 'maría', 'para', 'pero'],
#  'al mérito': ['galardón'],
#  'al no': ['haber', 'tener'],
#  'al notar': ['mi'],
#  'al número': ['de'],
#  'al otro': ['hasta', 'me'],
#  'al pabellón': ['para', 'pude'],
#  'al parecer': ['todo'],
#  'al parto': ['cuando', 'cómo', 'estoy'],
#  'al pasar': ['algunas', 'más', 'permanecía', 'por'],
#  'al pedal': ['correspondiente'],
#  'al personal': ['de'],
#  'al piso': ['de'],
#  'al poco': ['rato', 'tiempo'],
#  'al poder': ['de'],
#  'al primer': ['piso'],
#  'al principio': ['agradecí', 'era', 'hasta', 'me', 'mis', 'no', 'por'],
#  'al punto': ['de', 'que'],
#  'al que': ['debe', 'sería', 'un', 'ustedes'],
#  'al quedarnos': ['solos'],
#  'al quirófano': ['ahí', 'me', 'significaba'],
#  'al rato': ['dejó', 'volvió'],
#  'al rebelde': ['volver'],
#  'al recordar': ['esa'],
#  'al regalo': ['lo'],
#  'al regreso': ['nos'],
#  'al relajar': ['se'],
#  'al respecto': ['lo'],
#  'al resto': ['de', 'del'],
#  'al revés': ['porque'],
#  'al saber': ['de', 'que'],
#  'al sacarla': ['hacia'],
#  'al sacrificio': ['de'],
#  'al salir': ['de'],
#  'al segundo': ['piso'],
#  'al ser': ['llamados', 'sacada', 'trasladada'],
#  'al servicio': ['de'],
#  'al siguiente': ['carro'],
#  'al son': ['de'],
#  'al suyo': ['es'],
#  'al televisor': ['me'],
#  'al tensar': ['dicho'],
#  'al tercer': ['vagón'],
#  'al tomar': ['el'],
#  'al tope': ['de'],
#  'al traqueteo': ['sólo'],
#  'al traspasar': ['la'],
#  'al tren': ['sonó', 'tuvieron'],
#  'al término': ['de'],
#  'al típico': ['ajetreo'],
#  'al unísono': ['franz', 'sorpresa'],
#  'al urdir': ['los'],
#  'al vagón': ['quizás'],
#  'al ver': ['el', 'la', 'nuestro', 'sus', 'una'],
#  'al verla': ['aún', 'ella', 'muchos', 'padecer'],
#  'al verlo': ['acercarse'],
#  'al verlos': ['no', 'otra'],
#  'al verme': ['el', 'sonrió'],
#  'al viaje': ['no'],
#  'al volante': ['atravesamos', 'pero'],
#  'al volver': ['al', 'sentir'],
#  'alarma contra': ['incendios'],
#  'alarma es': ['un'],
#  'alarma la': ['casa', 'miraron'],
#  'alarma nada': ['dani'],
#  'alarma pero': ['no'],
#  'alarma por': ['qué'],
#  'albert einstein': ['moss'],
#  'alberto esquenazi': ['conocía', 'di', 'fisiatra'],
#  'alberto villarroel': ['amigo'],
#  'alcalde de': ['santiago'],
#  'alcance para': ['el'],
#  'alcancé recorrer': ['ni'],
#  'alcanzaban verse': ['subió'],
#  'alcanzadas antes': ['de'],
#  'alcanzado cada': ['cosa'],
#  'alcanzado mi': ['sueño'],
#  'alcanzar celebrar': ['el'],
#  'alcanzar metas': ['más'],
#  'alcanzar mis': ['metas'],
#  'alcanzar pero': ['nada'],
#  'alcanzaron tener': ['todo'],
#  'alcohol drogas': ['el'],
#  'alcohol ni': ['consumía'],
#  'alcé mi': ['brazo', 'pie'],
#  'alegraba estar': ['de'],
#  'alegrarme somos': ['cinco'],
#  'alegraron los': ['muros'],
#  'alegre conversación': ['le'],
#  'alegre me': ['despedí'],
#  'alegre no': ['supe'],
#  'alegre plena': ['sí'],
#  'alegremente cecilia': ['su'],
#  'alegremente con': ['algún'],
#  'alegremente varios': ['kinesiólogos'],
#  'alegres colores': ['el'],
#  'alegres el': ['viaje'],
#  'alegres entusiasmados': ['me'],
#  'alegres entusiastas': ['quienes'],
#  'alegres los': ['niños'],
#  'alegré de': ['sentirlo'],
#  'alegré mucho': ['de'],
#  'alegría cada': ['una'],
#  'alegría cuando': ['entendí', 'una'],
#  'alegría de': ['mis', 'ver'],
#  'alegría la': ['habitación'],
#  'alegría luego': ['el'],
#  'alegría no': ['menor'],
#  'alegría qué': ['avance'],
#  'alegría risas': ['mi'],
#  'alegría se': ['hablaba'],
#  'alegría yo': ['sabía'],
#  'alegría íbamos': ['en'],
#  'alegrías debo': ['reconocer'],
#  'alegrías desde': ['que'],
#  'alegrías más': ['grandes'],
#  'alegró con': ['mi'],
#  'alegró me': ['dio'],
#  'alegró no': ['sólo'],
#  'alejandro felipe': ['juan'],
#  'alejandro josé': ['luis'],
#  'alejandro juampi': ['diego'],
#  'alejandro uno': ['de'],
#  'alejarme de': ['mi'],
#  'alejarse la': ['ambulancia'],
#  'alejarse por': ['suerte'],
#  'alejarse salvo': ['el'],
#  'alejándola de': ['la'],
#  'alejó el': ['susto'],
#  'alejó los': ['del'],
#  'alejó por': ['primera'],
#  'alejó volvió': ['el'],
#  'alejó yo': ['recé'],
#  'alfiler en': ['mi'],
#  'algo abrigador': ['aconsejó'],
#  'algo ahora': ['pudo'],
#  'algo al': ['acostarme'],
#  'algo así': ['dios', 'fue', 'lloré', 'me', 'que', 'sería'],
#  'algo bueno': ['que'],
#  'algo comprado': ['en'],
#  'algo común': ['después'],
#  'algo con': ['las', 'ricardo'],
#  'algo concreto': ['en'],
#  'algo de': ['aire', 'lo'],
#  'algo debía': ['hacer'],
#  'algo delicioso': ['éramos'],
#  'algo dijo': ['la'],
#  'algo divertido': ['alguna'],
#  'algo en': ['lo', 'mi', 'su'],
#  'algo entonces': ['sabrás'],
#  'algo esotéricas': ['en'],
#  'algo faltaba': ['al'],
#  'algo familiar': ['me'],
#  'algo fijé': ['más'],
#  'algo hecho': ['por'],
#  'algo hoy': ['tengo'],
#  'algo húmedo': ['en'],
#  'algo idéntico': ['las'],
#  'algo imprudente': ['incluso'],
#  'algo inquieta': ['sobre'],
#  'algo insegura': ['me'],
#  'algo la': ['paula', 'simple'],
#  'algo las': ['piernas'],
#  'algo lo': ['que'],
#  'algo me': ['afirmé', 'encanta'],
#  'algo mejor': ['acepté'],
#  'algo muy': ['gracioso', 'importante', 'lindo'],
#  'algo más': ['me'],
#  'algo no': ['estaba', 'te'],
#  'algo nuevo': ['aunque', 'digno', 'me', 'más'],
#  'algo para': ['que'],
#  'algo pensé': ['en'],
#  'algo productivo': ['tengo'],
#  'algo que': ['hacía', 'me', 'nunca', 'recuerdo'],
#  'algo recuperada': ['de'],
#  'algo salga': ['bien'],
#  'algo similar': ['en', 'por'],
#  'algo sólo': ['puedo'],
#  'algo tan': ['dramático', 'importante', 'lejano'],
#  'algo tenía': ['que'],
#  'algo terrible': ['significa'],
#  'algo trataba': ['de'],
#  'algo una': ['promesa'],
#  'algo volvía': ['asearse'],
#  'algodón sobre': ['él'],
#  'alguien conmigo': ['ya'],
#  'alguien conocido': ['no'],
#  'alguien creería': ['que'],
#  'alguien de': ['ferrocarriles'],
#  'alguien decir': ['que'],
#  'alguien después': ['despertaba'],
#  'alguien en': ['bicicleta'],
#  'alguien gritó': ['viene'],
#  'alguien habría': ['oído'],
#  'alguien importante': ['era'],
#  'alguien listo': ['para'],
#  'alguien llamó': ['al'],
#  'alguien me': ['calmé'],
#  'alguien mi': ['compañero'],
#  'alguien muy': ['importante'],
#  'alguien más': ['fue', 'rezaba'],
#  'alguien nos': ['guió'],
#  'alguien para': ['ayudarme'],
#  'alguien parado': ['allí'],
#  'alguien podrá': ['ayudarme'],
#  'alguien por': ['favor'],
#  'alguien que': ['cuidara', 'grabara', 'me', 'podía'],
#  'alguien se': ['le', 'me', 'nos'],
#  'alguien sugirió': ['ir'],
#  'alguna con': ['respecto'],
#  'alguna copucha': ['sabrosa'],
#  'alguna de': ['ferrocarriles'],
#  'alguna dedicaba': ['un'],
#  'alguna droga': ['que'],
#  'alguna limitación': ['había'],
#  'alguna película': ['en'],
#  'alguna por': ['qué'],
#  'alguna solución': ['en'],
#  'alguna vez': ['en', 'fue', 'había', 'lo', 'retomar', 'yo'],
#  'algunas adaptaciones': ['mi'],
#  'algunas calles': ['daniela'],
#  'algunas caras': ['conocidas', 'de'],
#  'algunas compañeras': ['todo'],
#  'algunas conversaciones': ['entre'],
#  'algunas cosas': ['había', 'quedaron', 'siguen'],
#  'algunas cuadras': ['de'],
#  'algunas declaraciones': ['tales'],
#  'algunas flores': ['sus'],
#  'algunas fotografías': ['fue'],
#  'algunas fotos': ['nuestras'],
#  'algunas heridas': ['superficiales'],
#  'algunas horas': ['de', 'en', 'la', 'para'],
#  'algunas limitaciones': ['no'],
#  'algunas máquinas': ['de'],
#  'algunas palabras': ['con'],
#  'algunas personas': ['de'],
#  'algunas preguntas': ['sobre'],
#  'algunas radiografías': ['hacerme'],
#  'algunas semanas': ['se'],
#  'algunas veces': ['me'],
#  'alguno de': ['mis'],
#  'alguno me': ['miraba'],
#  'algunos ajustes': ['me'],
#  'algunos amigos': ['míos'],
#  'algunos aún': ['se'],
#  'algunos cabellos': ['en'],
#  'algunos compañeros': ['habían'],
#  'algunos datos': ['tres'],
#  'algunos de': ['los'],
#  'algunos días': ['almorzaba', 'vas'],
#  'algunos graciosos': ['tiraban'],
#  'algunos les': ['molestó'],
#  'algunos lloraban': ['entraron'],
#  'algunos meses': ['después'],
#  'algunos minutos': ['ahí', 'parada'],
#  'algunos nuevos': ['puntos'],
#  'algunos papás': ['de'],
#  'algunos participantes': ['de'],
#  'algunos paseos': ['fuera'],
#  'algunos pesos': ['quedé'],
#  'algunos problemas': ['al'],
#  'algunos regalos': ['esperándome'],
#  'algunos se': ['les'],
#  'algunos segundos': ['ricardo'],
#  'algún documento': ['pertenencia'],
#  'algún día': ['esas', 'podría', 'vuelvas'],
#  'algún familiar': ['recordé'],
#  'algún lado': ['sólo'],
#  'algún lugar': ['en'],
#  'algún miembro': ['de'],
#  'algún niño': ['inventaba', 'muerto'],
#  'algún nuevo': ['desafío'],
#  'algún percance': ['los'],
#  'algún rincón': ['de'],
#  'algún tema': ['de'],
#  'algún tiempo': ['mi'],
#  'aliento hicieron': ['muchas'],
#  'aliento yo': ['estaba'],
#  'alimentaban través': ['de'],
#  'alimentarlos necesité': ['mantener'],
#  'alimenticios parecidos': ['una'],
#  'aliviaban me': ['dejaban'],
#  'aliviada la': ['sola'],
#  'aliviada no': ['estaré'],
#  'alivianarle el': ['trabajo'],
#  'aliviar mis': ['dolores'],
#  'alivio cuando': ['finalmente'],
#  'alivio era': ['como'],
#  'alivio no': ['había'],
#  'alivio ya': ['no'],
#  'alivió muchísimo': ['sin'],
#  'allá con': ['marco'],
#  'allá de': ['sábado'],
#  'allá divisó': ['un'],
#  'allá donde': ['tenían'],
#  'allá en': ['los'],
#  'allá hay': ['otra'],
#  'allá la': ['entrada'],
#  'allá me': ['informó'],
#  'allá pero': ['no'],
#  'allá saludamos': ['unos'],
#  'allí darme': ['cuenta'],
#  'allí de': ['nuevo'],
#  'allí decidimos': ['que'],
#  'allí el': ['espacio'],
#  'allí era': ['una'],
#  'allí había': ['que'],
#  'allí la': ['pareja'],
#  'allí le': ['darán', 'preguntamos'],
#  'allí lo': ['que'],
#  'allí me': ['encontré'],
#  'allí mis': ['nuevas'],
#  'allí parientes': ['amigos'],
#  'allí podría': ['retribuirles'],
#  'allí trabajamos': ['en'],
#  'allí un': ['compañero'],
#  'allí una': ['pantalla'],
#  'allí vivimos': ['por'],
#  'alma aún': ['no'],
#  'almorcé con': ['uno'],
#  'almorzaba con': ['mi', 'mis'],
#  'almorzado sólo': ['una'],
#  'almorzar donde': ['siempre'],
#  'almorzar había': ['escuchado'],
#  'almorzar llamé': ['para'],
#  'almorzar que': ['siempre'],
#  'almorzarás en': ['tu'],
#  'almorzábamos juntas': ['nos'],
#  'almuerzo cuando': ['se'],
#  'almuerzo del': ['casino'],
#  'almuerzo deseas': ['convidar'],
#  'almuerzo era': ['las'],
#  'almuerzo lo': ['exitosa'],
#  'almuerzo mi': ['abuelita'],
#  'almuerzo nos': ['estuvimos'],
#  'almuerzo preparado': ['por'],
#  'almuerzo todos': ['otra'],
#  'almuerzo únicamente': ['necesitaba'],
#  'almuerzos balanceados': ['pero'],
#  'almuerzos me': ['parecían'],
#  'alojamiento proporcionado': ['por'],
#  'alojando al': ['lado'],
#  'alojando allí': ['la'],
#  'alojar ahí': ['tendría'],
#  'alojábamos mi': ['mamá'],
#  'alquiler préstamo': ['públicos'],
#  'alrededor con': ['felicidad'],
#  'alrededor creo': ['que'],
#  'alrededor de': ['cinco',
#   'ella',
#   'la',
#   'las',
#   'los',
#   'seis',
#   'siete',
#   'tres'],
#  'alrededor divisó': ['la'],
#  'alrededor entre': ['otras'],
#  'alrededor me': ['quedé'],
#  'alrededor pensar': ['que'],
#  ...}

# %% [markdown]
# #### 1.3. Predict the next word:

# %%
input_str = 'por josé'
print(input_str in my_dict)
# Out:
# True

# %%
from random import randint, seed

# %%
# Helper function that picks the following word.
def predict_next(a_nm1_gram):
    if a_nm1_gram not in my_dict:
        return '[desconocido]'  # opcional: puedes retornar None o un mensaje
    value_list_size = len(my_dict[a_nm1_gram])
    i_pick = randint(0, value_list_size - 1)  # importante: -1 para que esté dentro del rango
    return my_dict[a_nm1_gram][i_pick]                # Return the randomly chosen next word.

# %%
# Test 1: Predecir una palabra aleatoria
# asegúrate de usar un (n-1)-grama válido
print(predict_next(input_str))
# Out:
# luis

# %%
# Another test.
# Ver repeticiones para estimar probabilidad
for i in range(10):
    print(predict_next(input_str))
# Out:
# luis
# luis
# luis
# luis
# luis
# luis
# luis
# luis
# luis
# luis

# %% [markdown]
# #### 1.4. Predict a sequence:

# %%
# Initialize the random seed.
seed(123)

# %%
my_seed_str = 'al verme'
print(my_seed_str in my_dict)
# Out:
# True

# %%
a_nm1_gram = my_seed_str
output_string = my_seed_str                                         # Initialize the output string.
while a_nm1_gram in my_dict:
    next_word = predict_next(a_nm1_gram)
    output_string += " " + next_word
    words = nltk.word_tokenize(output_string)
    a_nm1_gram = ' '.join(words[-n+1:])  # actualiza el (n-1)-grama con las últimas n-1 palabras                           # Update a_nm1_gram.

# %%
# Output the predicted sequence.

print("Texto generado:")
print(output_string)
# Out:
# Texto generado:
# al verme el cariño agradecimiento hacia esas luces blancas rojas qué ocurría me paré asustada fui hacia la casa central maca ya voy llegando le avisé por teléfono con ellos observé que muchos terapeutas trabajaban con sus cuatro hijos tomó una ducha se metió la cama sacudí mis nubarrones mentales decidí que había recuperado caminaba solamente con la hora jamás lograría llegar tiempo al metro donde nos juntaríamos un grupo cohesionado estaban juntos desde primer año cómo iba lograrlo qué vergüenza me daban fuerza ánimo para continuar adelante al carro donde viajaba el resto fuimos ubicados en otro muy al final de pronto advirtió que sus perseguidores pasaban de largo estaba salvado así el rey no le importó manejar siempre ha sido una buena decisión el doctor enrique oyarzún para entrar al parto estoy segura de que sólo era un medio seguro terminada la hora jamás lograría llegar tiempo al metro tampoco quería depender de otros años créeme se pasa increíble después nos preocupamos de la puerta me encontré con quienes sufrían era mucho pero ricardo supo reconocer mi esfuerzo no había vuelta atrás pues ya había pagado mi cuota el miércoles 30 de octubre su trabajo en vez de mano el doctor pedro pablo rosso la directiva de medicina algunos días vas subir peldaños otros días los vas bajar mas eso no fue así como conocí linda una señora de unos sesenta tantos años quien causa de una bacteria de bastante cuidado por suerte viajaría en tren seguramente me quedé más tranquila la reinserción no sería tan difícil después de llevar más de felicidad comprobé una vez me bajé en la playa al campo paseos varios por el moss rehab institute cuando mi hermano josé ignacio tratando de contenerme yo aún profería gritos de auxilio pero sólo vi un muchacho escalando un cerro en silla de ruedas varios jóvenes con prótesis lanzándose con paracaídas qué debía hacer algo tenía que llamar al doctor esquenazi había estado callada mirando hacia fuera exclamó qué rico es estar viva esa frase dicha desde el gancho al relajar se cierra la fuerza para apoyar los antebrazos se paró detrás de los distintos cursos se comprometieron ayudarme con cariño sintió no poder despedirse de ella así que aprovechando que no iba morir en ese trance en fin al cabo el día en la maestranza de ferrocarriles venía vernos qué podían querer los mismos corredores de antes ver las cosas con más claridad no podía dormir se las arreglaba para darle un espacio la actividad física desde que tuve que abrir los distintos modelos de autos las adaptaciones que creía que todos iban espantarse entonces me di cuenta del gran esfuerzo mucho cariño mis metas se vaya cumpliendo ha pasado algunas cosas había que detener el tren para pedir noticias uno de los ojos de mi presencia me llenaron de besos por su cercanía al instituto además sería únicamente por una sensación de irrealidad yo viajaba en un casquete de plástico aunque no le quitaría las manos piernas sino también los de esas veces claudio contestó antes de irse leonor preguntó si daniela había perdido mis manos mis piernas aún no la calmaban me quedaba junto ella rezando rogando para que se olvidarán inmediatamente de ellos te van ver anunció mi abuelita desesperadas tratando de hacerse el serio me hicieron sentarme al borde de la entrada del escenario otro mar de gente se nos escapaba era todo tan burdo como que los estudios no le guste admitirlo pero debo reconocer que después de aparecer en televisión me ponía más feliz aún luego entró mi pieza al traspasar la puerta yo busqué sebastián con la hora justa respondió leonor si partimos de inmediato en mis antiguos compañeros un jueves llevé ropa para poder vernos todas las cosas maravillosas que he aprendido algo muy lindo fue pasar por eso había quedado bajo los rieles si pasara otro tren tengo que pedirle mi mamá para que algo comprado en una cola cuando mi hermano martín se ofreció ser mi escribidor me daba un poco con palabras de apoyo qué gratificante fue saber que ellos se estaban yend ...
